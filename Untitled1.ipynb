# %%
import requests
from bs4 import BeautifulSoup
import os
import pandas as pd
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 89.0.4389
# [WDM] - Get LATEST driver version for 89.0.4389
# [WDM] - Get LATEST driver version for 89.0.4389
# [WDM] - Trying to download new driver from https://chromedriver.storage.googleapis.com/89.0.4389.23/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\Courtney\.wdm\drivers\chromedriver\win32\89.0.4389.23]

# %%
images_url = "https://www.worldometers.info/geography/flags-of-the-world/"
browser.visit(images_url) 
myhtml = browser.html  
soup = BeautifulSoup(myhtml, 'html.parser')

# %%
#--------CREATE NEW LIST----------
country_flags = []

#--------USING BEAUTIFUL SOUP TO GET INTO HTML------------
divs = soup.find_all('div', class_="col-md-4")

#--------LOOPING THROUGH THE DIVS TO PULL IMAGE HREF AND COUNTRY NAME----
for div in divs:
    try:
        image_url = f'https://www.worldometers.info{div.a["href"]}'
        country_name = div.text
        #--------APPENDING INFO TO LIST------------------
        country_flags.append({'name': country_name, 'image_url': image_url})
    except:
        print('error found')
# Out:
# error found

# %%
country_flags
# Out:
# [{'name': 'Afghanistan',
#   'image_url': 'https://www.worldometers.info/img/flags/af-flag.gif'},
#  {'name': 'Albania',
#   'image_url': 'https://www.worldometers.info/img/flags/al-flag.gif'},
#  {'name': 'Algeria',
#   'image_url': 'https://www.worldometers.info/img/flags/ag-flag.gif'},
#  {'name': 'Andorra',
#   'image_url': 'https://www.worldometers.info/img/flags/an-flag.gif'},
#  {'name': 'Angola',
#   'image_url': 'https://www.worldometers.info/img/flags/ao-flag.gif'},
#  {'name': 'Antigua and Barbuda',
#   'image_url': 'https://www.worldometers.info/img/flags/ac-flag.gif'},
#  {'name': 'Argentina',
#   'image_url': 'https://www.worldometers.info/img/flags/ar-flag.gif'},
#  {'name': 'Armenia',
#   'image_url': 'https://www.worldometers.info/img/flags/am-flag.gif'},
#  {'name': 'Australia',
#   'image_url': 'https://www.worldometers.info/img/flags/as-flag.gif'},
#  {'name': 'Austria',
#   'image_url': 'https://www.worldometers.info/img/flags/au-flag.gif'},
#  {'name': 'Azerbaijan',
#   'image_url': 'https://www.worldometers.info/img/flags/aj-flag.gif'},
#  {'name': 'Bahamas',
#   'image_url': 'https://www.worldometers.info/img/flags/bf-flag.gif'},
#  {'name': 'Bahrain',
#   'image_url': 'https://www.worldometers.info/img/flags/ba-flag.gif'},
#  {'name': 'Bangladesh',
#   'image_url': 'https://www.worldometers.info/img/flags/bg-flag.gif'},
#  {'name': 'Barbados',
#   'image_url': 'https://www.worldometers.info/img/flags/bb-flag.gif'},
#  {'name': 'Belarus',
#   'image_url': 'https://www.worldometers.info/img/flags/bo-flag.gif'},
#  {'name': 'Belgium',
#   'image_url': 'https://www.worldometers.info/img/flags/be-flag.gif'},
#  {'name': 'Belize',
#   'image_url': 'https://www.worldometers.info/img/flags/bh-flag.gif'},
#  {'name': 'Benin',
#   'image_url': 'https://www.worldometers.info/img/flags/bn-flag.gif'},
#  {'name': 'Bhutan',
#   'image_url': 'https://www.worldometers.info/img/flags/bt-flag.gif'},
#  {'name': 'Bolivia',
#   'image_url': 'https://www.worldometers.info/img/flags/bl-flag.gif'},
#  {'name': 'Bosnia and Herzegovina',
#   'image_url': 'https://www.worldometers.info/img/flags/bk-flag.gif'},
#  {'name': 'Botswana',
#   'image_url': 'https://www.worldometers.info/img/flags/bc-flag.gif'},
#  {'name': 'Brazil',
#   'image_url': 'https://www.worldometers.info/img/flags/br-flag.gif'},
#  {'name': 'Brunei ',
#   'image_url': 'https://www.worldometers.info/img/flags/bx-flag.gif'},
#  {'name': 'Bulgaria',
#   'image_url': 'https://www.worldometers.info/img/flags/bu-flag.gif'},
#  {'name': 'Burkina Faso',
#   'image_url': 'https://www.worldometers.info/img/flags/uv-flag.gif'},
#  {'name': 'Burundi',
#   'image_url': 'https://www.worldometers.info/img/flags/by-flag.gif'},
#  {'name': "Côte d'Ivoire",
#   'image_url': 'https://www.worldometers.info/img/flags/iv-flag.gif'},
#  {'name': 'Cabo Verde',
#   'image_url': 'https://www.worldometers.info/img/flags/cv-flag.gif'},
#  {'name': 'Cambodia',
#   'image_url': 'https://www.worldometers.info/img/flags/cb-flag.gif'},
#  {'name': 'Cameroon',
#   'image_url': 'https://www.worldometers.info/img/flags/cm-flag.gif'},
#  {'name': 'Canada',
#   'image_url': 'https://www.worldometers.info/img/flags/ca-flag.gif'},
#  {'name': 'CAR',
#   'image_url': 'https://www.worldometers.info/img/flags/ct-flag.gif'},
#  {'name': 'Chad',
#   'image_url': 'https://www.worldometers.info/img/flags/cd-flag.gif'},
#  {'name': 'Chile',
#   'image_url': 'https://www.worldometers.info/img/flags/ci-flag.gif'},
#  {'name': 'China',
#   'image_url': 'https://www.worldometers.info/img/flags/ch-flag.gif'},
#  {'name': 'Colombia',
#   'image_url': 'https://www.worldometers.info/img/flags/co-flag.gif'},
#  {'name': 'Comoros',
#   'image_url': 'https://www.worldometers.info/img/flags/cn-flag.gif'},
#  {'name': 'Congo',
#   'image_url': 'https://www.worldometers.info/img/flags/cg-flag.gif'},
#  {'name': 'Costa Rica',
#   'image_url': 'https://www.worldometers.info/img/flags/cs-flag.gif'},
#  {'name': 'Croatia',
#   'image_url': 'https://www.worldometers.info/img/flags/hr-flag.gif'},
#  {'name': 'Cuba',
#   'image_url': 'https://www.worldometers.info/img/flags/cu-flag.gif'},
#  {'name': 'Cyprus',
#   'image_url': 'https://www.worldometers.info/img/flags/cy-flag.gif'},
#  {'name': 'Czechia',
#   'image_url': 'https://www.worldometers.info/img/flags/ez-flag.gif'},
#  {'name': 'Denmark',
#   'image_url': 'https://www.worldometers.info/img/flags/da-flag.gif'},
#  {'name': 'Djibouti',
#   'image_url': 'https://www.worldometers.info/img/flags/dj-flag.gif'},
#  {'name': 'Dominica',
#   'image_url': 'https://www.worldometers.info/img/flags/do-flag.gif'},
#  {'name': 'Dominican Republic',
#   'image_url': 'https://www.worldometers.info/img/flags/dr-flag.gif'},
#  {'name': 'DPRK',
#   'image_url': 'https://www.worldometers.info/img/flags/kn-flag.gif'},
#  {'name': 'DRC',
#   'image_url': 'https://www.worldometers.info/img/flags/congo-flag.gif'},
#  {'name': 'Ecuador',
#   'image_url': 'https://www.worldometers.info/img/flags/ec-flag.gif'},
#  {'name': 'Egypt',
#   'image_url': 'https://www.worldometers.info/img/flags/eg-flag.gif'},
#  {'name': 'El Salvador',
#   'image_url': 'https://www.worldometers.info/img/flags/es-flag.gif'},
#  {'name': 'Equatorial Guinea',
#   'image_url': 'https://www.worldometers.info/img/flags/ek-flag.gif'},
#  {'name': 'Eritrea',
#   'image_url': 'https://www.worldometers.info/img/flags/er-flag.gif'},
#  {'name': 'Estonia',
#   'image_url': 'https://www.worldometers.info/img/flags/en-flag.gif'},
#  {'name': 'Eswatini',
#   'image_url': 'https://www.worldometers.info/img/flags/wz-flag.gif'},
#  {'name': 'Ethiopia',
#   'image_url': 'https://www.worldometers.info/img/flags/et-flag.gif'},
#  {'name': 'Fiji',
#   'image_url': 'https://www.worldometers.info/img/flags/fj-flag.gif'},
#  {'name': 'Finland',
#   'image_url': 'https://www.worldometers.info/img/flags/fi-flag.gif'},
#  {'name': 'France',
#   'image_url': 'https://www.worldometers.info/img/flags/fr-flag.gif'},
#  {'name': 'Gabon',
#   'image_url': 'https://www.worldometers.info/img/flags/gb-flag.gif'},
#  {'name': 'Gambia',
#   'image_url': 'https://www.worldometers.info/img/flags/ga-flag.gif'},
#  {'name': 'Georgia',
#   'image_url': 'https://www.worldometers.info/img/flags/gg-flag.gif'},
#  {'name': 'Germany',
#   'image_url': 'https://www.worldometers.info/img/flags/gm-flag.gif'},
#  {'name': 'Ghana',
#   'image_url': 'https://www.worldometers.info/img/flags/gh-flag.gif'},
#  {'name': 'Greece',
#   'image_url': 'https://www.worldometers.info/img/flags/gr-flag.gif'},
#  {'name': 'Grenada',
#   'image_url': 'https://www.worldometers.info/img/flags/gj-flag.gif'},
#  {'name': 'Guatemala',
#   'image_url': 'https://www.worldometers.info/img/flags/gt-flag.gif'},
#  {'name': 'Guinea',
#   'image_url': 'https://www.worldometers.info/img/flags/gv-flag.gif'},
#  {'name': 'Guinea-Bissau',
#   'image_url': 'https://www.worldometers.info/img/flags/pu-flag.gif'},
#  {'name': 'Guyana',
#   'image_url': 'https://www.worldometers.info/img/flags/gy-flag.gif'},
#  {'name': 'Haiti',
#   'image_url': 'https://www.worldometers.info/img/flags/ha-flag.gif'},
#  {'name': 'Holy See',
#   'image_url': 'https://www.worldometers.info/img/flags/vt-flag.gif'},
#  {'name': 'Honduras',
#   'image_url': 'https://www.worldometers.info/img/flags/ho-flag.gif'},
#  {'name': 'Hungary',
#   'image_url': 'https://www.worldometers.info/img/flags/hu-flag.gif'},
#  {'name': 'Iceland',
#   'image_url': 'https://www.worldometers.info/img/flags/ic-flag.gif'},
#  {'name': 'India',
#   'image_url': 'https://www.worldometers.info/img/flags/in-flag.gif'},
#  {'name': 'Indonesia',
#   'image_url': 'https://www.worldometers.info/img/flags/id-flag.gif'},
#  {'name': 'Iran',
#   'image_url': 'https://www.worldometers.info/img/flags/ir-flag.gif'},
#  {'name': 'Iraq',
#   'image_url': 'https://www.worldometers.info/img/flags/iz-flag.gif'},
#  {'name': 'Ireland',
#   'image_url': 'https://www.worldometers.info/img/flags/ei-flag.gif'},
#  {'name': 'Israel',
#   'image_url': 'https://www.worldometers.info/img/flags/is-flag.gif'},
#  {'name': 'Italy',
#   'image_url': 'https://www.worldometers.info/img/flags/it-flag.gif'},
#  {'name': 'Jamaica',
#   'image_url': 'https://www.worldometers.info/img/flags/jm-flag.gif'},
#  {'name': 'Japan',
#   'image_url': 'https://www.worldometers.info/img/flags/ja-flag.gif'},
#  {'name': 'Jordan',
#   'image_url': 'https://www.worldometers.info/img/flags/jo-flag.gif'},
#  {'name': 'Kazakhstan',
#   'image_url': 'https://www.worldometers.info/img/flags/kz-flag.gif'},
#  {'name': 'Kenya',
#   'image_url': 'https://www.worldometers.info/img/flags/ke-flag.gif'},
#  {'name': 'Kiribati',
#   'image_url': 'https://www.worldometers.info/img/flags/kr-flag.gif'},
#  {'name': 'Kuwait',
#   'image_url': 'https://www.worldometers.info/img/flags/ku-flag.gif'},
#  {'name': 'Kyrgyzstan',
#   'image_url': 'https://www.worldometers.info/img/flags/kg-flag.gif'},
#  {'name': 'Laos',
#   'image_url': 'https://www.worldometers.info/img/flags/la-flag.gif'},
#  {'name': 'Latvia',
#   'image_url': 'https://www.worldometers.info/img/flags/lg-flag.gif'},
#  {'name': 'Lebanon',
#   'image_url': 'https://www.worldometers.info/img/flags/le-flag.gif'},
#  {'name': 'Lesotho',
#   'image_url': 'https://www.worldometers.info/img/flags/lt-flag.gif'},
#  {'name': 'Liberia',
#   'image_url': 'https://www.worldometers.info/img/flags/li-flag.gif'},
#  {'name': 'Libya',
#   'image_url': 'https://www.worldometers.info/img/flags/ly-flag.gif'},
#  {'name': 'Liechtenstein',
#   'image_url': 'https://www.worldometers.info/img/flags/ls-flag.gif'},
#  {'name': 'Lithuania',
#   'image_url': 'https://www.worldometers.info/img/flags/lh-flag.gif'},
#  {'name': 'Luxembourg',
#   'image_url': 'https://www.worldometers.info/img/flags/lu-flag.gif'},
#  {'name': 'Madagascar',
#   'image_url': 'https://www.worldometers.info/img/flags/ma-flag.gif'},
#  {'name': 'Malawi',
#   'image_url': 'https://www.worldometers.info/img/flags/mi-flag.gif'},
#  {'name': 'Malaysia',
#   'image_url': 'https://www.worldometers.info/img/flags/my-flag.gif'},
#  {'name': 'Maldives',
#   'image_url': 'https://www.worldometers.info/img/flags/mv-flag.gif'},
#  {'name': 'Mali',
#   'image_url': 'https://www.worldometers.info/img/flags/ml-flag.gif'},
#  {'name': 'Malta',
#   'image_url': 'https://www.worldometers.info/img/flags/mt-flag.gif'},
#  {'name': 'Marshall Islands',
#   'image_url': 'https://www.worldometers.info/img/flags/rm-flag.gif'},
#  {'name': 'Mauritania',
#   'image_url': 'https://www.worldometers.info/img/flags/mr-flag.gif'},
#  {'name': 'Mauritius',
#   'image_url': 'https://www.worldometers.info/img/flags/mp-flag.gif'},
#  {'name': 'Mexico',
#   'image_url': 'https://www.worldometers.info/img/flags/mx-flag.gif'},
#  {'name': 'Micronesia',
#   'image_url': 'https://www.worldometers.info/img/flags/fm-flag.gif'},
#  {'name': 'Moldova',
#   'image_url': 'https://www.worldometers.info/img/flags/md-flag.gif'},
#  {'name': 'Monaco',
#   'image_url': 'https://www.worldometers.info/img/flags/mn-flag.gif'},
#  {'name': 'Mongolia',
#   'image_url': 'https://www.worldometers.info/img/flags/mg-flag.gif'},
#  {'name': 'Montenegro',
#   'image_url': 'https://www.worldometers.info/img/flags/mj-flag.gif'},
#  {'name': 'Morocco',
#   'image_url': 'https://www.worldometers.info/img/flags/mo-flag.gif'},
#  {'name': 'Mozambique',
#   'image_url': 'https://www.worldometers.info/img/flags/mz-flag.gif'},
#  {'name': 'Myanmar',
#   'image_url': 'https://www.worldometers.info/img/flags/bm-flag.gif'},
#  {'name': 'Namibia',
#   'image_url': 'https://www.worldometers.info/img/flags/wa-flag.gif'},
#  {'name': 'Nauru',
#   'image_url': 'https://www.worldometers.info/img/flags/nr-flag.gif'},
#  {'name': 'Nepal',
#   'image_url': 'https://www.worldometers.info/img/flags/np-flag.gif'},
#  {'name': 'Netherlands',
#   'image_url': 'https://www.worldometers.info/img/flags/nl-flag.gif'},
#  {'name': 'New Zealand',
#   'image_url': 'https://www.worldometers.info/img/flags/nz-flag.gif'},
#  {'name': 'Nicaragua',
#   'image_url': 'https://www.worldometers.info/img/flags/nu-flag.gif'},
#  {'name': 'Niger',
#   'image_url': 'https://www.worldometers.info/img/flags/ng-flag.gif'},
#  {'name': 'Nigeria',
#   'image_url': 'https://www.worldometers.info/img/flags/ni-flag.gif'},
#  {'name': 'North Macedonia',
#   'image_url': 'https://www.worldometers.info/img/flags/mk-flag.gif'},
#  {'name': 'Norway',
#   'image_url': 'https://www.worldometers.info/img/flags/no-flag.gif'},
#  {'name': 'Oman',
#   'image_url': 'https://www.worldometers.info/img/flags/mu-flag.gif'},
#  {'name': 'Pakistan',
#   'image_url': 'https://www.worldometers.info/img/flags/pk-flag.gif'},
#  {'name': 'Palau',
#   'image_url': 'https://www.worldometers.info/img/flags/ps-flag.gif'},
#  {'name': 'Panama',
#   'image_url': 'https://www.worldometers.info/img/flags/pm-flag.gif'},
#  {'name': 'Papua New Guinea',
#   'image_url': 'https://www.worldometers.info/img/flags/pp-flag.gif'},
#  {'name': 'Paraguay',
#   'image_url': 'https://www.worldometers.info/img/flags/pa-flag.gif'},
#  {'name': 'Peru',
#   'image_url': 'https://www.worldometers.info/img/flags/pe-flag.gif'},
#  {'name': 'Philippines',
#   'image_url': 'https://www.worldometers.info/img/flags/rp-flag.gif'},
#  {'name': 'Poland',
#   'image_url': 'https://www.worldometers.info/img/flags/pl-flag.gif'},
#  {'name': 'Portugal',
#   'image_url': 'https://www.worldometers.info/img/flags/po-flag.gif'},
#  {'name': 'Qatar',
#   'image_url': 'https://www.worldometers.info/img/flags/qa-flag.gif'},
#  {'name': 'Romania',
#   'image_url': 'https://www.worldometers.info/img/flags/ro-flag.gif'},
#  {'name': 'Russia',
#   'image_url': 'https://www.worldometers.info/img/flags/rs-flag.gif'},
#  {'name': 'Rwanda',
#   'image_url': 'https://www.worldometers.info/img/flags/rw-flag.gif'},
#  {'name': 'Saint Kitts and Nevis',
#   'image_url': 'https://www.worldometers.info/img/flags/sc-flag.gif'},
#  {'name': 'Saint Lucia',
#   'image_url': 'https://www.worldometers.info/img/flags/st-flag.gif'},
#  {'name': 'Samoa',
#   'image_url': 'https://www.worldometers.info/img/flags/ws-flag.gif'},
#  {'name': 'San Marino',
#   'image_url': 'https://www.worldometers.info/img/flags/sm-flag.gif'},
#  {'name': 'Sao Tome and Principe',
#   'image_url': 'https://www.worldometers.info/img/flags/tp-flag.gif'},
#  {'name': 'Saudi Arabia',
#   'image_url': 'https://www.worldometers.info/img/flags/sa-flag.gif'},
#  {'name': 'Senegal',
#   'image_url': 'https://www.worldometers.info/img/flags/sg-flag.gif'},
#  {'name': 'Serbia',
#   'image_url': 'https://www.worldometers.info/img/flags/ri-flag.gif'},
#  {'name': 'Seychelles',
#   'image_url': 'https://www.worldometers.info/img/flags/se-flag.gif'},
#  {'name': 'Sierra Leone',
#   'image_url': 'https://www.worldometers.info/img/flags/sl-flag.gif'},
#  {'name': 'Singapore',
#   'image_url': 'https://www.worldometers.info/img/flags/sn-flag.gif'},
#  {'name': 'Slovakia',
#   'image_url': 'https://www.worldometers.info/img/flags/lo-flag.gif'},
#  {'name': 'Slovenia',
#   'image_url': 'https://www.worldometers.info/img/flags/si-flag.gif'},
#  {'name': 'Solomon Islands',
#   'image_url': 'https://www.worldometers.info/img/flags/bp-flag.gif'},
#  {'name': 'Somalia',
#   'image_url': 'https://www.worldometers.info/img/flags/so-flag.gif'},
#  {'name': 'South Africa',
#   'image_url': 'https://www.worldometers.info/img/flags/sf-flag.gif'},
#  {'name': 'South Korea',
#   'image_url': 'https://www.worldometers.info/img/flags/ks-flag.gif'},
#  {'name': 'South Sudan',
#   'image_url': 'https://www.worldometers.info/img/flags/od-flag.gif'},
#  {'name': 'Spain',
#   'image_url': 'https://www.worldometers.info/img/flags/sp-flag.gif'},
#  {'name': 'Sri Lanka',
#   'image_url': 'https://www.worldometers.info/img/flags/ce-flag.gif'},
#  {'name': 'St. Vincent Grenadines',
#   'image_url': 'https://www.worldometers.info/img/flags/vc-flag.gif'},
#  {'name': 'State of Palestine',
#   'image_url': 'https://www.worldometers.info/img/flags/palestine-flag.gif'},
#  {'name': 'Sudan',
#   'image_url': 'https://www.worldometers.info/img/flags/su-flag.gif'},
#  {'name': 'Suriname',
#   'image_url': 'https://www.worldometers.info/img/flags/ns-flag.gif'},
#  {'name': 'Sweden',
#   'image_url': 'https://www.worldometers.info/img/flags/sw-flag.gif'},
#  {'name': 'Switzerland',
#   'image_url': 'https://www.worldometers.info/img/flags/sz-flag.gif'},
#  {'name': 'Syria',
#   'image_url': 'https://www.worldometers.info/img/flags/sy-flag.gif'},
#  {'name': 'Tajikistan',
#   'image_url': 'https://www.worldometers.info/img/flags/ti-flag.gif'},
#  {'name': 'Tanzania',
#   'image_url': 'https://www.worldometers.info/img/flags/tz-flag.gif'},
#  {'name': 'Thailand',
#   'image_url': 'https://www.worldometers.info/img/flags/th-flag.gif'},
#  {'name': 'Timor-Leste',
#   'image_url': 'https://www.worldometers.info/img/flags/tt-flag.gif'},
#  {'name': 'Togo',
#   'image_url': 'https://www.worldometers.info/img/flags/to-flag.gif'},
#  {'name': 'Tonga',
#   'image_url': 'https://www.worldometers.info/img/flags/tn-flag.gif'},
#  {'name': 'Trinidad and Tobago',
#   'image_url': 'https://www.worldometers.info/img/flags/td-flag.gif'},
#  {'name': 'Tunisia',
#   'image_url': 'https://www.worldometers.info/img/flags/ts-flag.gif'},
#  {'name': 'Turkey',
#   'image_url': 'https://www.worldometers.info/img/flags/tu-flag.gif'},
#  {'name': 'Turkmenistan',
#   'image_url': 'https://www.worldometers.info/img/flags/tx-flag.gif'},
#  {'name': 'Tuvalu',
#   'image_url': 'https://www.worldometers.info/img/flags/tv-flag.gif'},
#  {'name': 'U.A.E.',
#   'image_url': 'https://www.worldometers.info/img/flags/ae-flag.gif'},
#  {'name': 'U.K.',
#   'image_url': 'https://www.worldometers.info/img/flags/uk-flag.gif'},
#  {'name': 'U.S.',
#   'image_url': 'https://www.worldometers.info/img/flags/us-flag.gif'},
#  {'name': 'Uganda',
#   'image_url': 'https://www.worldometers.info/img/flags/ug-flag.gif'},
#  {'name': 'Ukraine',
#   'image_url': 'https://www.worldometers.info/img/flags/up-flag.gif'},
#  {'name': 'Uruguay',
#   'image_url': 'https://www.worldometers.info/img/flags/uy-flag.gif'},
#  {'name': 'Uzbekistan',
#   'image_url': 'https://www.worldometers.info/img/flags/uz-flag.gif'},
#  {'name': 'Vanuatu',
#   'image_url': 'https://www.worldometers.info/img/flags/nh-flag.gif'},
#  {'name': 'Venezuela',
#   'image_url': 'https://www.worldometers.info/img/flags/ve-flag.gif'},
#  {'name': 'Vietnam',
#   'image_url': 'https://www.worldometers.info/img/flags/vm-flag.gif'},
#  {'name': 'Yemen',
#   'image_url': 'https://www.worldometers.info/img/flags/ym-flag.gif'},
#  {'name': 'Zambia',
#   'image_url': 'https://www.worldometers.info/img/flags/za-flag.gif'},
#  {'name': 'Zimbabwe',
#   'image_url': 'https://www.worldometers.info/img/flags/zi-flag.gif'}]

# %%
#--------PUT LIST INTO DATAFRAME TO USE LATER----------------
flag_df = pd.DataFrame(country_flags)

#--------UPDATE COUNTRY NAMES TO MATCH DEMO DATAFRAMES-------
flag_df['name'] = flag_df['name'].replace(['U.A.E.','U.S.', 'U.K.', 'DRC', 'CAR', 'Czechia', 'St. Vincent Grenadines'],['United Arab Emirates','United States','United Kingdom', 'DR Congo', 'Central Aftican Republic', 'Czech Republic (Czechia)', 'St. Vincent & Grenadines'])

# %%
#----WEBSCRAPE DIFF WEBSITE FOR DEMO--------
#OPEN BROWSER AND NAVIGATE TO WEBSITE FOR DEMO-----
demo_url = "https://www.worldometers.info/world-population/population-by-country/"
browser.visit(demo_url) 
myhtml = browser.html  
soup = BeautifulSoup(myhtml, 'html.parser')

# %%
#---------CREATE NEW LIST-----------
country_demo = []

#---------USING BEAUTIFUL SOUP TO GET INTO HTML-------
#-----ONLY PULLING IN HALF OF THE TABLE ROWS DUE TO DIFF CLASS NAMES------
table = soup.find_all('tbody')
table_rows = soup.find_all('tr', class_='odd')

# %%
#----------LOOPING THROUGH THE TABLE ROWS TO GET TABLE DETAILS------
for row in table_rows:
    country = row.find('a').text
    table_data = row.find_all('td')
    population = table_data[2].text
    density = table_data[5].text
    land_size = table_data[6].text
    med_age = table_data[9].text
    urban_pop = table_data[10].text
    #------ADDING INFO TO LIST-----------
    country_demo.append({'name': country, 'population': population, 'density': density, 'land-size': land_size, 'median_age': med_age, 'urban_pop': urban_pop})

# %%
#---------USING BEAUTIFUL SOUP TO GET INTO HTML-------
#-----PULLING IN SECOND HALF OF THE TABLE ROWS DUE TO DIFF CLASS NAMES------
table_rows = soup.find_all('tr', class_='even')

#----------LOOPING THROUGH THE TABLE ROWS TO GET TABLE DETAILS------
for row in table_rows:
    country = row.find('a').text
    table_data = row.find_all('td')
    population = table_data[2].text
    density = table_data[5].text
    land_size = table_data[6].text
    med_age = table_data[9].text
    urban_pop = table_data[10].text
    #------ADDING INFO TO LIST-----------
    country_demo.append({'name': country, 'population': population, 'density': density, 'land-size': land_size, 'median_age': med_age, 'urban_pop': urban_pop})

# %%
#--------PUT LIST INTO DATAFRAME-------------
demo_df = pd.DataFrame(country_demo)

#---------MERGE BOTH DATAFRAMES--------------
country_demo_df = pd.merge(demo_df, flag_df, on='name', how='left')

# %%
#---------SCRAPE FOR LATITUDE AND LONGITUDE----------
#--OPEN BROWSER AND  NAVIAGATE TO PAGE---------------
coord_url = "https://developers.google.com/public-data/docs/canonical/countries_csv"
browser.visit(coord_url) 
myhtml = browser.html  
soup = BeautifulSoup(myhtml, 'html.parser')

#--------CREATE NEW LIST FOR LAT/LONG-----------------------
country_coord = []

# %%
#---------USING BEAUTIFUL SOUP TO GET INTO HTML-------------------
table = soup.find('tbody')
table_rows = table.find_all('tr')

#---------LOOPING THROUGH ROWS---------------------------------
for row in table_rows[1:]:
    table_data = row.find_all('td')
    country = table_data[3].text
    lat = table_data[1].text
    long = table_data[2].text
    # APPEND TO COORDINATE LIST
    country_coord.append({'name': country, 'latitude': lat, 'longitude':long})

# %%
#------------PUT LIST INTO DATAFRAME--------------------------------
country_coord_df = pd.DataFrame(country_coord)

#------------MERGE WITH MERGED DATAFRAME---------------------------
country_df = pd.merge(country_demo_df, country_coord_df, on='name', how='left')

# %%
#---------PUSH MERGED DATAFRAME TO SQLITE DATABASE TO USE LATER----------
from sqlalchemy import create_engine
engine = create_engine('sqlite:///static/data/climateDB.db', echo=True)
sqlite_connection = engine.connect()

sqlite_table = 'country_demo'
country_df.to_sql(sqlite_table, sqlite_connection, if_exists='replace')

sqlite_connection.close()
# Out:
# 2021-05-03 18:51:41,413 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-05-03 18:51:41,415 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-03 18:51:41,420 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-05-03 18:51:41,424 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-03 18:51:41,443 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("country_demo")
# 2021-05-03 18:51:41,446 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-03 18:51:41,449 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("country_demo")
# 2021-05-03 18:51:41,456 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-03 18:51:41,471 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE country_demo (
# 	"index" BIGINT,
# 	name TEXT,
# 	population TEXT,
# 	density TEXT,
# 	"land-size" TEXT,
# 	median_age TEXT,
# 	urban_pop TEXT,
# 	image_url TEXT,
# 	latitude TEXT,
# 	longitude TEXT
# )
#
#
# 2021-05-03 18:51:41,476 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-03 18:51:41,511 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-05-03 18:51:41,518 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_country_demo_index ON country_demo ("index")
# 2021-05-03 18:51:41,522 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-03 18:51:41,574 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-05-03 18:51:41,582 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-05-03 18:51:41,586 INFO sqlalchemy.engine.base.Engine INSERT INTO country_demo ("index", name, population, density, "land-size", median_age, urban_pop, image_url, latitude, longitude) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-05-03 18:51:41,587 INFO sqlalchemy.engine.base.Engine ((0, 'China', '1,439,323,776', '153', '9,388,211', '38', '61 %', 'https://www.worldometers.info/img/flags/ch-flag.gif', '35.86166', '104.195397'), (1, 'United States', '331,002,651', '36', '9,147,420', '38', '83 %', 'https://www.worldometers.info/img/flags/us-flag.gif', '37.09024', '-95.712891'), (2, 'Pakistan', '220,892,340', '287', '770,880', '23', '35 %', 'https://www.worldometers.info/img/flags/pk-flag.gif', '30.375321', '69.345116'), (3, 'Nigeria', '206,139,589', '226', '910,770', '18', '52 %', 'https://www.worldometers.info/img/flags/ni-flag.gif', '9.081999', '8.675277'), (4, 'Russia', '145,934,462', '9', '16,376,870', '40', '74 %', 'https://www.worldometers.info/img/flags/rs-flag.gif', '61.52401', '105.318756'), (5, 'Japan', '126,476,461', '347', '364,555', '48', '92 %', 'https://www.worldometers.info/img/flags/ja-flag.gif', '36.204824', '138.252924'), (6, 'Philippines', '109,581,078', '368', '298,170', '26', '47 %', 'https://www.worldometers.info/img/flags/rp-flag.gif', '12.879721', '121.774017'), (7, 'Vietnam', '97,338,579', '314', '310,070', '32', '38 %', 'https://www.worldometers.info/img/flags/vm-flag.gif', '14.058324', '108.277199')  ... displaying 10 of 235 total bound parameter sets ...  (233, 'Falkland Islands', '3,480', '0', '12,170', 'N.A.', '66 %', None, None, None), (234, 'Tokelau', '1,357', '136', '10', 'N.A.', '0 %', None, '-8.967363', '-171.855881'))
# 2021-05-03 18:51:41,591 INFO sqlalchemy.engine.base.Engine COMMIT
