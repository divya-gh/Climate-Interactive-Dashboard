# %%
# dependencies
import pandas as pd
import numpy as np
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, join, outerjoin, MetaData, Table

# %%
# create engine to hawaii.sqlite
connect_string = "sqlite:///static/data/climateDB.db"

# reflect the tables
engine = create_engine(connect_string) 

# reflect an existing database into a new model
Base = automap_base()

# reflect the tables
Base.prepare(engine, reflect =True)

# %%
Base.classes.keys()
# Out:
# ['CO2_emission', 'country_demo', 'temp_change']

# %%
# Save references to each table
Emission = Base.classes.CO2_emission
Temp_change = Base.classes.temp_change
Country_demo = Base.classes.country_demo

# %%
# Create a session (link) from Python to the sqlite DB
session = Session(bind = engine)

#Filter the data for the year >= 1961
results_emission = session.query(Emission).filter(Emission.Year >= 1961)
#print(results)

# %%
emission_df = pd.read_sql(results_emission.statement, session.connection())
results_temp = session.query(Temp_change)
temp_df = pd.read_sql(results_temp.statement, session.connection())



# filter Meteorological year
meteor_df = temp_df.loc[temp_df["Months"] == 'Meteorological year' ]
meteor_id_df = meteor_df.copy()

# Calculate avg temp per Meteorological year
meteor_id_df['avg_temp']= round(meteor_id_df.mean(axis =1),3)
meteor_id_df
# Out:
#       field1                                     Area               Months  \
# 16        32                              Afghanistan  Meteorological year
# 33        66                                  Albania  Meteorological year
# 50       100                                  Algeria  Meteorological year
# 67       168                                  Andorra  Meteorological year
# 84       202                                   Angola  Meteorological year
# ...      ...                                      ...                  ...
# 3311    9518        Low Income Food Deficit Countries  Meteorological year
# 3328    9552  Net Food Importing Developing Countries  Meteorological year
# 3345    9586                        Annex I countries  Meteorological year
# 3362    9620                    Non-Annex I countries  Meteorological year
# 3379    9654                                     OECD  Meteorological year
#
#                  Element Unit   1961   1962   1963   1964   1965  ...   2011  \
# 16    Temperature change   °C -0.080 -0.120  0.882 -0.727 -0.200  ...  1.342
# 33    Temperature change   °C  0.631  0.339  0.084 -0.171 -0.392  ...  1.123
# 50    Temperature change   °C  0.186  0.101  0.045  0.212 -0.135  ...  1.492
# 67    Temperature change   °C  0.749  0.110 -0.755  0.305 -0.500  ...  1.643
# 84    Temperature change   °C  0.053 -0.139 -0.176 -0.215 -0.181  ...  0.708
# ...                  ...  ...    ...    ...    ...    ...    ...  ...    ...
# 3311  Temperature change   °C -0.085 -0.186  0.072 -0.207 -0.224  ...  0.872
# 3328  Temperature change   °C -0.015 -0.096  0.116 -0.204 -0.155  ...  0.878
# 3345  Temperature change   °C  0.453  0.161  0.172 -0.366 -0.409  ...  1.090
# 3362  Temperature change   °C  0.029 -0.059  0.149 -0.174 -0.092  ...  0.801
# 3379  Temperature change   °C  0.165 -0.009  0.134 -0.190 -0.385  ...  0.805
#
#        2012   2013   2014   2015   2016   2017   2018   2019  avg_temp
# 16    0.102  1.237  0.474  1.096  1.473  1.483  1.524  0.893     0.958
# 33    1.603  1.495  1.399  1.725  1.697  1.337  2.232  1.911     1.577
# 50    1.238  1.267  1.774  1.224  1.866  1.630  1.326  1.224     2.366
# 67    1.233  0.794  1.899  1.619  1.917  1.853  1.826  1.871     3.480
# 84    0.401  0.910  0.726  1.260  1.534  0.808  1.264  1.694     3.773
# ...     ...    ...    ...    ...    ...    ...    ...    ...       ...
# 3311  0.618  0.875  0.820  1.061  1.292  1.276  1.094  1.244   159.063
# 3328  0.692  0.977  0.971  1.269  1.374  1.292  1.222  1.412   159.672
# 3345  1.512  1.109  1.119  1.616  2.098  1.607  1.397  1.627   160.359
# 3362  0.768  0.955  1.003  1.276  1.366  1.316  1.234  1.361   160.793
# 3379  1.274  0.991  0.811  1.282  1.850  1.349  1.088  1.297   161.386
#
# [201 rows x 65 columns]

# %%
# rename = ['Brunei ','DR Congo','Caribbean Netherlands']
# to_country = ['Brunei Darussalam', 'Democratic Republic of the Congo','Caribbean']
# for i in range(len(rename)):
#     print(to_country[i])
#     update_name = session.query(Country_demo).filter(Country_demo.name ==rename[i])
#     update_name.name = to_country[i]
# session.commit()
# update_name.name

# %%
results_Demo = session.query(Country_demo)
demo_df = pd.read_sql(results_Demo.statement, session.connection(),index_col='index')
session.close()

# %%
demo_sorted_df = demo_df.sort_values(by=["name"]).reset_index(drop=True)
demo_sorted_df = demo_sorted_df.rename({"name":"Area","population":"Population",
                                        "density":"Density",
                                        "land-size":"Land Size","image_url":"Images",
                                        "latitude":"Lat","longitude":"Lng"},axis='columns')
demo_sorted_df
# Out:
#                 Area  Population Density  Land Size median_age urban_pop  \
# 0        Afghanistan  38,928,346      60    652,860         18      25 %
# 1            Albania   2,877,797     105     27,400         36      63 %
# 2            Algeria  43,851,044      18  2,381,740         29      73 %
# 3     American Samoa      55,191     276        200       N.A.      88 %
# 4            Andorra      77,265     164        470       N.A.      88 %
# ..               ...         ...     ...        ...        ...       ...
# 230  Wallis & Futuna      11,239      80        140       N.A.       0 %
# 231   Western Sahara     597,339       2    266,000         28      87 %
# 232            Yemen  29,825,964      56    527,970         20      38 %
# 233           Zambia  18,383,955      25    743,390         18      45 %
# 234         Zimbabwe  14,862,924      38    386,850         19      38 %
#
#                                                 Images         Lat  \
# 0    https://www.worldometers.info/img/flags/af-fla...    33.93911
# 1    https://www.worldometers.info/img/flags/al-fla...   41.153332
# 2    https://www.worldometers.info/img/flags/ag-fla...   28.033886
# 3                                                 None  -14.270972
# 4    https://www.worldometers.info/img/flags/an-fla...   42.546245
# ..                                                 ...         ...
# 230                                               None        None
# 231                                               None   24.215527
# 232  https://www.worldometers.info/img/flags/ym-fla...   15.552727
# 233  https://www.worldometers.info/img/flags/za-fla...  -13.133897
# 234  https://www.worldometers.info/img/flags/zi-fla...  -19.015438
#
#              Lng
# 0      67.709953
# 1      20.168331
# 2       1.659626
# 3    -170.132217
# 4       1.601554
# ..           ...
# 230         None
# 231   -12.885834
# 232    48.516388
# 233    27.849332
# 234    29.154857
#
# [235 rows x 9 columns]

# %%
# demo_countries = demo_sorted_df['name'].tolist()
# temp_countries = meteor_df['Area'].tolist()

# countries = []
# for country in temp_countries:
#     for demo in demo_countries:
#         if country== demo:
#             countries.append(country)
            
# len(countries)
# for country in temp_countries:
#     if country not in countries:
#         print(country)

# %%
# for country in demo_countries:
#     if country not in countries:
#         print(country)

# %%
#calculate overall avg_co2 emission per country
avg_co2 =  emission_df.groupby("Entity").agg({'AnnualCO2emissions':'mean'})
avg_co2 = round(avg_co2/1000000,3) ## converting GT to Mega ton for the tooltip
avg_co2.reset_index(inplace=True)
avg_co2
# Out:
#                         Entity  AnnualCO2emissions
# 0                  Afghanistan               3.036
# 1                       Africa             726.391
# 2                      Albania               4.503
# 3                      Algeria              74.340
# 4                      Andorra               0.246
# ..                         ...                 ...
# 229  Wallis and Futuna Islands               0.008
# 230                      World           22816.567
# 231                      Yemen              10.082
# 232                     Zambia               3.289
# 233                   Zimbabwe              10.514
#
# [234 rows x 2 columns]

# %%
avg_co2 = avg_co2.rename({'Entity':'Area', 'AnnualCO2emissions':'AnnualCO2emissions'}, axis='columns')

avg_co2
# Out:
#                           Area  AnnualCO2emissions
# 0                  Afghanistan               3.036
# 1                       Africa             726.391
# 2                      Albania               4.503
# 3                      Algeria              74.340
# 4                      Andorra               0.246
# ..                         ...                 ...
# 229  Wallis and Futuna Islands               0.008
# 230                      World           22816.567
# 231                      Yemen              10.082
# 232                     Zambia               3.289
# 233                   Zimbabwe              10.514
#
# [234 rows x 2 columns]

# %%
#Merge Temp_change by meteor year per country to Avg_Co2 Emission df
merged_co2_country =meteor_id_df.merge(avg_co2, how = 'left',  on="Area")

#find null
merged_co2_country.isna().sum()
#fill 0
merged_co2_country = merged_co2_country.fillna(0)
#find null again
merged_co2_country.isna().sum()

#merge population data to Temp and Co2 Emission df
popu_data = merged_co2_country.merge(demo_sorted_df, how = 'left', on ="Area" )

popu_data = popu_data[['Area', 'Population','Density', 'Land Size', 'Images', 'Lat','Lng']].fillna(0).set_index("Area",drop=True)
popu_data
# Out:
#                                          Population Density  Land Size  \
# Area
# Afghanistan                              38,928,346      60    652,860
# Albania                                   2,877,797     105     27,400
# Algeria                                  43,851,044      18  2,381,740
# Andorra                                      77,265     164        470
# Angola                                   32,866,272      26  1,246,700
# ...                                             ...     ...        ...
# Low Income Food Deficit Countries                 0       0          0
# Net Food Importing Developing Countries           0       0          0
# Annex I countries                                 0       0          0
# Non-Annex I countries                             0       0          0
# OECD                                              0       0          0
#
#                                                                                     Images  \
# Area
# Afghanistan                              https://www.worldometers.info/img/flags/af-fla...
# Albania                                  https://www.worldometers.info/img/flags/al-fla...
# Algeria                                  https://www.worldometers.info/img/flags/ag-fla...
# Andorra                                  https://www.worldometers.info/img/flags/an-fla...
# Angola                                   https://www.worldometers.info/img/flags/ao-fla...
# ...                                                                                    ...
# Low Income Food Deficit Countries                                                        0
# Net Food Importing Developing Countries                                                  0
# Annex I countries                                                                        0
# Non-Annex I countries                                                                    0
# OECD                                                                                     0
#
#                                                 Lat        Lng
# Area
# Afghanistan                                33.93911  67.709953
# Albania                                   41.153332  20.168331
# Algeria                                   28.033886   1.659626
# Andorra                                   42.546245   1.601554
# Angola                                   -11.202692  17.873887
# ...                                             ...        ...
# Low Income Food Deficit Countries                 0          0
# Net Food Importing Developing Countries           0          0
# Annex I countries                                 0          0
# Non-Annex I countries                             0          0
# OECD                                              0          0
#
# [201 rows x 6 columns]

# %%
merged_co2_country.set_index("Area",inplace=True)
merged_co2_country
# Out:
#                                          field1               Months  \
# Area
# Afghanistan                                  32  Meteorological year
# Albania                                      66  Meteorological year
# Algeria                                     100  Meteorological year
# Andorra                                     168  Meteorological year
# Angola                                      202  Meteorological year
# ...                                         ...                  ...
# Low Income Food Deficit Countries          9518  Meteorological year
# Net Food Importing Developing Countries    9552  Meteorological year
# Annex I countries                          9586  Meteorological year
# Non-Annex I countries                      9620  Meteorological year
# OECD                                       9654  Meteorological year
#
#                                                     Element Unit   1961  \
# Area
# Afghanistan                              Temperature change   °C -0.080
# Albania                                  Temperature change   °C  0.631
# Algeria                                  Temperature change   °C  0.186
# Andorra                                  Temperature change   °C  0.749
# Angola                                   Temperature change   °C  0.053
# ...                                                     ...  ...    ...
# Low Income Food Deficit Countries        Temperature change   °C -0.085
# Net Food Importing Developing Countries  Temperature change   °C -0.015
# Annex I countries                        Temperature change   °C  0.453
# Non-Annex I countries                    Temperature change   °C  0.029
# OECD                                     Temperature change   °C  0.165
#
#                                           1962   1963   1964   1965   1966  \
# Area
# Afghanistan                             -0.120  0.882 -0.727 -0.200  0.176
# Albania                                  0.339  0.084 -0.171 -0.392  0.551
# Algeria                                  0.101  0.045  0.212 -0.135  0.404
# Andorra                                  0.110 -0.755  0.305 -0.500  0.403
# Angola                                  -0.139 -0.176 -0.215 -0.181  0.193
# ...                                        ...    ...    ...    ...    ...
# Low Income Food Deficit Countries       -0.186  0.072 -0.207 -0.224  0.080
# Net Food Importing Developing Countries -0.096  0.116 -0.204 -0.155  0.129
# Annex I countries                        0.161  0.172 -0.366 -0.409  0.270
# Non-Annex I countries                   -0.059  0.149 -0.174 -0.092  0.151
# OECD                                    -0.009  0.134 -0.190 -0.385 -0.166
#
#                                          ...   2012   2013   2014   2015  \
# Area                                     ...
# Afghanistan                              ...  0.102  1.237  0.474  1.096
# Albania                                  ...  1.603  1.495  1.399  1.725
# Algeria                                  ...  1.238  1.267  1.774  1.224
# Andorra                                  ...  1.233  0.794  1.899  1.619
# Angola                                   ...  0.401  0.910  0.726  1.260
# ...                                      ...    ...    ...    ...    ...
# Low Income Food Deficit Countries        ...  0.618  0.875  0.820  1.061
# Net Food Importing Developing Countries  ...  0.692  0.977  0.971  1.269
# Annex I countries                        ...  1.512  1.109  1.119  1.616
# Non-Annex I countries                    ...  0.768  0.955  1.003  1.276
# OECD                                     ...  1.274  0.991  0.811  1.282
#
#                                           2016   2017   2018   2019  avg_temp  \
# Area
# Afghanistan                              1.473  1.483  1.524  0.893     0.958
# Albania                                  1.697  1.337  2.232  1.911     1.577
# Algeria                                  1.866  1.630  1.326  1.224     2.366
# Andorra                                  1.917  1.853  1.826  1.871     3.480
# Angola                                   1.534  0.808  1.264  1.694     3.773
# ...                                        ...    ...    ...    ...       ...
# Low Income Food Deficit Countries        1.292  1.276  1.094  1.244   159.063
# Net Food Importing Developing Countries  1.374  1.292  1.222  1.412   159.672
# Annex I countries                        2.098  1.607  1.397  1.627   160.359
# Non-Annex I countries                    1.366  1.316  1.234  1.361   160.793
# OECD                                     1.850  1.349  1.088  1.297   161.386
#
#                                          AnnualCO2emissions
# Area
# Afghanistan                                           3.036
# Albania                                               4.503
# Algeria                                              74.340
# Andorra                                               0.246
# Angola                                               11.971
# ...                                                     ...
# Low Income Food Deficit Countries                     0.000
# Net Food Importing Developing Countries               0.000
# Annex I countries                                     0.000
# Non-Annex I countries                                 0.000
# OECD                                                  0.000
#
# [201 rows x 65 columns]

# %%
New_Countires = merged_co2_country.index
New_Countires
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Anguilla',
#        'Antarctica', 'Argentina', 'Australia', 'Austria',
#        ...
#        'Polynesia', 'European Union', 'Least Developed Countries',
#        'Land Locked Developing Countries', 'Small Island Developing States',
#        'Low Income Food Deficit Countries',
#        'Net Food Importing Developing Countries', 'Annex I countries',
#        'Non-Annex I countries', 'OECD'],
#       dtype='object', name='Area', length=201)

# %%
#Create a dictionary holding above values
 #meta ={
#    'country' : country_name,
#    'demo_info' : [web scraped data],
#    'tool_tip' : [{'c_name': country_name,
#                'avg_temp':avg_temp,
#                'avg_co2' : new_Avg_c02,
#                'population':population from web scraping
#                }]
#   } 

#New Code---------------------------------------------------

meta = []

for country in New_Countires:
    temp_co2_obj = {
                    "Country":country,
                    "Avg Temp Change":merged_co2_country.loc[country,"avg_temp"],
                    "Avg Co2 Change":merged_co2_country.loc[country,"AnnualCO2emissions"],
                    "Population":popu_data.loc[country,"Population"],
                    "Density":popu_data.loc[country,"Density"],
                    "Land Size":popu_data.loc[country,"Land Size"],
                    "Images":popu_data.loc[country,"Images"],
                    "Lat":popu_data.loc[country,"Lat"],
                    "Lng":popu_data.loc[country,"Lng"],
                    }
    meta.append(temp_co2_obj)
meta
# Out:
# [{'Country': 'Afghanistan',
#   'Avg Temp Change': 0.958,
#   'Avg Co2 Change': 3.036,
#   'Population': '38,928,346',
#   'Density': '60',
#   'Land Size': '652,860',
#   'Images': 'https://www.worldometers.info/img/flags/af-flag.gif',
#   'Lat': '33.93911',
#   'Lng': '67.709953'},
#  {'Country': 'Albania',
#   'Avg Temp Change': 1.577,
#   'Avg Co2 Change': 4.503,
#   'Population': '2,877,797',
#   'Density': '105',
#   'Land Size': '27,400',
#   'Images': 'https://www.worldometers.info/img/flags/al-flag.gif',
#   'Lat': '41.153332',
#   'Lng': '20.168331'},
#  {'Country': 'Algeria',
#   'Avg Temp Change': 2.366,
#   'Avg Co2 Change': 74.34,
#   'Population': '43,851,044',
#   'Density': '18',
#   'Land Size': '2,381,740',
#   'Images': 'https://www.worldometers.info/img/flags/ag-flag.gif',
#   'Lat': '28.033886',
#   'Lng': '1.659626'},
#  {'Country': 'Andorra',
#   'Avg Temp Change': 3.48,
#   'Avg Co2 Change': 0.246,
#   'Population': '77,265',
#   'Density': '164',
#   'Land Size': '470',
#   'Images': 'https://www.worldometers.info/img/flags/an-flag.gif',
#   'Lat': '42.546245',
#   'Lng': '1.601554'},
#  {'Country': 'Angola',
#   'Avg Temp Change': 3.773,
#   'Avg Co2 Change': 11.971,
#   'Population': '32,866,272',
#   'Density': '26',
#   'Land Size': '1,246,700',
#   'Images': 'https://www.worldometers.info/img/flags/ao-flag.gif',
#   'Lat': '-11.202692',
#   'Lng': '17.873887'},
#  {'Country': 'Anguilla',
#   'Avg Temp Change': 4.185,
#   'Avg Co2 Change': 0.056,
#   'Population': '15,003',
#   'Density': '167',
#   'Land Size': '90',
#   'Images': 0,
#   'Lat': '18.220554',
#   'Lng': '-63.068615'},
#  {'Country': 'Antarctica',
#   'Avg Temp Change': 4.655,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Argentina',
#   'Avg Temp Change': 5.894,
#   'Avg Co2 Change': 124.014,
#   'Population': '45,195,774',
#   'Density': '17',
#   'Land Size': '2,736,690',
#   'Images': 'https://www.worldometers.info/img/flags/ar-flag.gif',
#   'Lat': '-38.416097',
#   'Lng': '-63.616672'},
#  {'Country': 'Australia',
#   'Avg Temp Change': 7.76,
#   'Avg Co2 Change': 273.351,
#   'Population': '25,499,884',
#   'Density': '3',
#   'Land Size': '7,682,300',
#   'Images': 'https://www.worldometers.info/img/flags/as-flag.gif',
#   'Lat': '-25.274398',
#   'Lng': '133.775136'},
#  {'Country': 'Austria',
#   'Avg Temp Change': 8.636,
#   'Avg Co2 Change': 59.374,
#   'Population': '9,006,398',
#   'Density': '109',
#   'Land Size': '82,409',
#   'Images': 'https://www.worldometers.info/img/flags/au-flag.gif',
#   'Lat': '47.516231',
#   'Lng': '14.550072'},
#  {'Country': 'Bahamas',
#   'Avg Temp Change': 9.45,
#   'Avg Co2 Change': 2.751,
#   'Population': '393,244',
#   'Density': '39',
#   'Land Size': '10,010',
#   'Images': 'https://www.worldometers.info/img/flags/bf-flag.gif',
#   'Lat': '25.03428',
#   'Lng': '-77.39628'},
#  {'Country': 'Bahrain',
#   'Avg Temp Change': 10.288,
#   'Avg Co2 Change': 14.123,
#   'Population': '1,701,575',
#   'Density': '2,239',
#   'Land Size': '760',
#   'Images': 'https://www.worldometers.info/img/flags/ba-flag.gif',
#   'Lat': '25.930414',
#   'Lng': '50.637772'},
#  {'Country': 'Bangladesh',
#   'Avg Temp Change': 10.391,
#   'Avg Co2 Change': 24.771,
#   'Population': '164,689,383',
#   'Density': '1,265',
#   'Land Size': '130,170',
#   'Images': 'https://www.worldometers.info/img/flags/bg-flag.gif',
#   'Lat': '23.684994',
#   'Lng': '90.356331'},
#  {'Country': 'Belize',
#   'Avg Temp Change': 13.49,
#   'Avg Co2 Change': 0.308,
#   'Population': '397,628',
#   'Density': '17',
#   'Land Size': '22,810',
#   'Images': 'https://www.worldometers.info/img/flags/bh-flag.gif',
#   'Lat': '17.189877',
#   'Lng': '-88.49765'},
#  {'Country': 'Benin',
#   'Avg Temp Change': 14.086,
#   'Avg Co2 Change': 1.885,
#   'Population': '12,123,200',
#   'Density': '108',
#   'Land Size': '112,760',
#   'Images': 'https://www.worldometers.info/img/flags/bn-flag.gif',
#   'Lat': '9.30769',
#   'Lng': '2.315834'},
#  {'Country': 'Bhutan',
#   'Avg Temp Change': 14.486,
#   'Avg Co2 Change': 0.293,
#   'Population': '771,608',
#   'Density': '20',
#   'Land Size': '38,117',
#   'Images': 'https://www.worldometers.info/img/flags/bt-flag.gif',
#   'Lat': '27.514162',
#   'Lng': '90.433601'},
#  {'Country': 'Bolivia',
#   'Avg Temp Change': 15.15,
#   'Avg Co2 Change': 8.383,
#   'Population': '11,673,021',
#   'Density': '11',
#   'Land Size': '1,083,300',
#   'Images': 'https://www.worldometers.info/img/flags/bl-flag.gif',
#   'Lat': '-16.290154',
#   'Lng': '-63.588653'},
#  {'Country': 'Botswana',
#   'Avg Temp Change': 16.193,
#   'Avg Co2 Change': 2.416,
#   'Population': '2,351,627',
#   'Density': '4',
#   'Land Size': '566,730',
#   'Images': 'https://www.worldometers.info/img/flags/bc-flag.gif',
#   'Lat': '-22.328474',
#   'Lng': '24.684866'},
#  {'Country': 'Brazil',
#   'Avg Temp Change': 16.94,
#   'Avg Co2 Change': 246.389,
#   'Population': '212,559,417',
#   'Density': '25',
#   'Land Size': '8,358,140',
#   'Images': 'https://www.worldometers.info/img/flags/br-flag.gif',
#   'Lat': '-14.235004',
#   'Lng': '-51.92528'},
#  {'Country': 'British Virgin Islands',
#   'Avg Temp Change': 17.21,
#   'Avg Co2 Change': 0.091,
#   'Population': '30,231',
#   'Density': '202',
#   'Land Size': '150',
#   'Images': 0,
#   'Lat': '18.420695',
#   'Lng': '-64.639968'},
#  {'Country': 'Brunei',
#   'Avg Temp Change': 17.912,
#   'Avg Co2 Change': 5.288,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Bulgaria',
#   'Avg Temp Change': 18.545,
#   'Avg Co2 Change': 59.913,
#   'Population': '6,948,445',
#   'Density': '64',
#   'Land Size': '108,560',
#   'Images': 'https://www.worldometers.info/img/flags/bu-flag.gif',
#   'Lat': '42.733883',
#   'Lng': '25.48583'},
#  {'Country': 'Burkina Faso',
#   'Avg Temp Change': 19.159,
#   'Avg Co2 Change': 1.019,
#   'Population': '20,903,273',
#   'Density': '76',
#   'Land Size': '273,600',
#   'Images': 'https://www.worldometers.info/img/flags/uv-flag.gif',
#   'Lat': '12.238333',
#   'Lng': '-1.561593'},
#  {'Country': 'Cambodia',
#   'Avg Temp Change': 20.738,
#   'Avg Co2 Change': 2.42,
#   'Population': '16,718,965',
#   'Density': '95',
#   'Land Size': '176,520',
#   'Images': 'https://www.worldometers.info/img/flags/cb-flag.gif',
#   'Lat': '12.565679',
#   'Lng': '104.990963'},
#  {'Country': 'Cameroon',
#   'Avg Temp Change': 21.362,
#   'Avg Co2 Change': 3.409,
#   'Population': '26,545,863',
#   'Density': '56',
#   'Land Size': '472,710',
#   'Images': 'https://www.worldometers.info/img/flags/cm-flag.gif',
#   'Lat': '7.369722',
#   'Lng': '12.354722'},
#  {'Country': 'Canada',
#   'Avg Temp Change': 22.093,
#   'Avg Co2 Change': 455.258,
#   'Population': '37,742,154',
#   'Density': '4',
#   'Land Size': '9,093,510',
#   'Images': 'https://www.worldometers.info/img/flags/ca-flag.gif',
#   'Lat': '56.130366',
#   'Lng': '-106.346771'},
#  {'Country': 'Central African Republic',
#   'Avg Temp Change': 23.053,
#   'Avg Co2 Change': 0.2,
#   'Population': '4,829,767',
#   'Density': '8',
#   'Land Size': '622,980',
#   'Images': 0,
#   'Lat': '6.611111',
#   'Lng': '20.939444'},
#  {'Country': 'Chad',
#   'Avg Temp Change': 23.648,
#   'Avg Co2 Change': 0.423,
#   'Population': '16,425,864',
#   'Density': '13',
#   'Land Size': '1,259,200',
#   'Images': 'https://www.worldometers.info/img/flags/cd-flag.gif',
#   'Lat': '15.454166',
#   'Lng': '18.732207'},
#  {'Country': 'Channel Islands',
#   'Avg Temp Change': 24.29,
#   'Avg Co2 Change': 0.0,
#   'Population': '173,863',
#   'Density': '915',
#   'Land Size': '190',
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Chile',
#   'Avg Temp Change': 24.515,
#   'Avg Co2 Change': 42.422,
#   'Population': '19,116,201',
#   'Density': '26',
#   'Land Size': '743,532',
#   'Images': 'https://www.worldometers.info/img/flags/ci-flag.gif',
#   'Lat': '-35.675147',
#   'Lng': '-71.542969'},
#  {'Country': 'China',
#   'Avg Temp Change': 25.418,
#   'Avg Co2 Change': 3642.462,
#   'Population': '1,439,323,776',
#   'Density': '153',
#   'Land Size': '9,388,211',
#   'Images': 'https://www.worldometers.info/img/flags/ch-flag.gif',
#   'Lat': '35.86166',
#   'Lng': '104.195397'},
#  {'Country': 'China, Hong Kong SAR',
#   'Avg Temp Change': 25.815,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'China, Macao SAR',
#   'Avg Temp Change': 26.382,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'China, mainland',
#   'Avg Temp Change': 27.119,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'China, Taiwan Province of',
#   'Avg Temp Change': 27.463,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Cocos (Keeling) Islands',
#   'Avg Temp Change': 28.554,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Colombia',
#   'Avg Temp Change': 29.22,
#   'Avg Co2 Change': 53.284,
#   'Population': '50,882,891',
#   'Density': '46',
#   'Land Size': '1,109,500',
#   'Images': 'https://www.worldometers.info/img/flags/co-flag.gif',
#   'Lat': '4.570868',
#   'Lng': '-74.297333'},
#  {'Country': "Côte d'Ivoire",
#   'Avg Temp Change': 32.211,
#   'Avg Co2 Change': 0.0,
#   'Population': '26,378,274',
#   'Density': '83',
#   'Land Size': '318,000',
#   'Images': 'https://www.worldometers.info/img/flags/iv-flag.gif',
#   'Lat': '7.539989',
#   'Lng': '-5.54708'},
#  {'Country': 'Cuba',
#   'Avg Temp Change': 33.301,
#   'Avg Co2 Change': 25.556,
#   'Population': '11,326,616',
#   'Density': '106',
#   'Land Size': '106,440',
#   'Images': 'https://www.worldometers.info/img/flags/cu-flag.gif',
#   'Lat': '21.521757',
#   'Lng': '-77.781167'},
#  {'Country': 'Cyprus',
#   'Avg Temp Change': 33.755,
#   'Avg Co2 Change': 4.756,
#   'Population': '1,207,359',
#   'Density': '131',
#   'Land Size': '9,240',
#   'Images': 'https://www.worldometers.info/img/flags/cy-flag.gif',
#   'Lat': '35.126413',
#   'Lng': '33.429859'},
#  {'Country': "Democratic People's Republic of Korea",
#   'Avg Temp Change': 35.631,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Democratic Republic of the Congo',
#   'Avg Temp Change': 36.014,
#   'Avg Co2 Change': 2.645,
#   'Population': '5,518,087',
#   'Density': '16',
#   'Land Size': '341,500',
#   'Images': 'https://www.worldometers.info/img/flags/cg-flag.gif',
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Denmark',
#   'Avg Temp Change': 36.873,
#   'Avg Co2 Change': 52.663,
#   'Population': '5,792,202',
#   'Density': '137',
#   'Land Size': '42,430',
#   'Images': 'https://www.worldometers.info/img/flags/da-flag.gif',
#   'Lat': '56.26392',
#   'Lng': '9.501785'},
#  {'Country': 'Dominica',
#   'Avg Temp Change': 37.618,
#   'Avg Co2 Change': 0.078,
#   'Population': '71,986',
#   'Density': '96',
#   'Land Size': '750',
#   'Images': 'https://www.worldometers.info/img/flags/do-flag.gif',
#   'Lat': '15.414999',
#   'Lng': '-61.370976'},
#  {'Country': 'Dominican Republic',
#   'Avg Temp Change': 38.459,
#   'Avg Co2 Change': 12.171,
#   'Population': '10,847,910',
#   'Density': '225',
#   'Land Size': '48,320',
#   'Images': 'https://www.worldometers.info/img/flags/dr-flag.gif',
#   'Lat': '18.735693',
#   'Lng': '-70.162651'},
#  {'Country': 'Ecuador',
#   'Avg Temp Change': 38.936,
#   'Avg Co2 Change': 19.336,
#   'Population': '17,643,054',
#   'Density': '71',
#   'Land Size': '248,360',
#   'Images': 'https://www.worldometers.info/img/flags/ec-flag.gif',
#   'Lat': '-1.831239',
#   'Lng': '-78.183406'},
#  {'Country': 'Egypt',
#   'Avg Temp Change': 39.327,
#   'Avg Co2 Change': 100.831,
#   'Population': '102,334,404',
#   'Density': '103',
#   'Land Size': '995,450',
#   'Images': 'https://www.worldometers.info/img/flags/eg-flag.gif',
#   'Lat': '26.820553',
#   'Lng': '30.802498'},
#  {'Country': 'El Salvador',
#   'Avg Temp Change': 40.071,
#   'Avg Co2 Change': 3.72,
#   'Population': '6,486,205',
#   'Density': '313',
#   'Land Size': '20,720',
#   'Images': 'https://www.worldometers.info/img/flags/es-flag.gif',
#   'Lat': '13.794185',
#   'Lng': '-88.89653'},
#  {'Country': 'Eswatini',
#   'Avg Temp Change': 42.295,
#   'Avg Co2 Change': 0.682,
#   'Population': '1,160,164',
#   'Density': '67',
#   'Land Size': '17,200',
#   'Images': 'https://www.worldometers.info/img/flags/wz-flag.gif',
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Faeroe Islands',
#   'Avg Temp Change': 44.532,
#   'Avg Co2 Change': 0.493,
#   'Population': '48,863',
#   'Density': '35',
#   'Land Size': '1,396',
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Fiji',
#   'Avg Temp Change': 45.15,
#   'Avg Co2 Change': 0.859,
#   'Population': '896,445',
#   'Density': '49',
#   'Land Size': '18,270',
#   'Images': 'https://www.worldometers.info/img/flags/fj-flag.gif',
#   'Lat': '-16.578193',
#   'Lng': '179.414413'},
#  {'Country': 'Finland',
#   'Avg Temp Change': 46.007,
#   'Avg Co2 Change': 49.48,
#   'Population': '5,540,720',
#   'Density': '18',
#   'Land Size': '303,890',
#   'Images': 'https://www.worldometers.info/img/flags/fi-flag.gif',
#   'Lat': '61.92411',
#   'Lng': '25.748151'},
#  {'Country': 'France',
#   'Avg Temp Change': 46.512,
#   'Avg Co2 Change': 404.926,
#   'Population': '65,273,511',
#   'Density': '119',
#   'Land Size': '547,557',
#   'Images': 'https://www.worldometers.info/img/flags/fr-flag.gif',
#   'Lat': '46.227638',
#   'Lng': '2.213749'},
#  {'Country': 'French Guiana',
#   'Avg Temp Change': 46.954,
#   'Avg Co2 Change': 0.0,
#   'Population': '298,682',
#   'Density': '4',
#   'Land Size': '82,200',
#   'Images': 0,
#   'Lat': '3.933889',
#   'Lng': '-53.125782'},
#  {'Country': 'French Polynesia',
#   'Avg Temp Change': 47.32,
#   'Avg Co2 Change': 0.467,
#   'Population': '280,908',
#   'Density': '77',
#   'Land Size': '3,660',
#   'Images': 0,
#   'Lat': '-17.679742',
#   'Lng': '-149.406843'},
#  {'Country': 'Gabon',
#   'Avg Temp Change': 48.447,
#   'Avg Co2 Change': 4.309,
#   'Population': '2,225,734',
#   'Density': '9',
#   'Land Size': '257,670',
#   'Images': 'https://www.worldometers.info/img/flags/gb-flag.gif',
#   'Lat': '-0.803689',
#   'Lng': '11.609444'},
#  {'Country': 'Gambia',
#   'Avg Temp Change': 49.508,
#   'Avg Co2 Change': 0.226,
#   'Population': '2,416,668',
#   'Density': '239',
#   'Land Size': '10,120',
#   'Images': 'https://www.worldometers.info/img/flags/ga-flag.gif',
#   'Lat': '13.443182',
#   'Lng': '-15.310139'},
#  {'Country': 'Germany',
#   'Avg Temp Change': 50.518,
#   'Avg Co2 Change': 944.5,
#   'Population': '83,783,942',
#   'Density': '240',
#   'Land Size': '348,560',
#   'Images': 'https://www.worldometers.info/img/flags/gm-flag.gif',
#   'Lat': '51.165691',
#   'Lng': '10.451526'},
#  {'Country': 'Ghana',
#   'Avg Temp Change': 50.899,
#   'Avg Co2 Change': 5.748,
#   'Population': '31,072,940',
#   'Density': '137',
#   'Land Size': '227,540',
#   'Images': 'https://www.worldometers.info/img/flags/gh-flag.gif',
#   'Lat': '7.946527',
#   'Lng': '-1.023194'},
#  {'Country': 'Gibraltar',
#   'Avg Temp Change': 51.585,
#   'Avg Co2 Change': 0.0,
#   'Population': '33,691',
#   'Density': '3,369',
#   'Land Size': '10',
#   'Images': 0,
#   'Lat': '36.137741',
#   'Lng': '-5.345374'},
#  {'Country': 'Greece',
#   'Avg Temp Change': 51.872,
#   'Avg Co2 Change': 66.055,
#   'Population': '10,423,054',
#   'Density': '81',
#   'Land Size': '128,900',
#   'Images': 'https://www.worldometers.info/img/flags/gr-flag.gif',
#   'Lat': '39.074208',
#   'Lng': '21.824312'},
#  {'Country': 'Greenland',
#   'Avg Temp Change': 52.469,
#   'Avg Co2 Change': 0.46,
#   'Population': '56,770',
#   'Density': '0',
#   'Land Size': '410,450',
#   'Images': 0,
#   'Lat': '71.706936',
#   'Lng': '-42.604303'},
#  {'Country': 'Grenada',
#   'Avg Temp Change': 53.012,
#   'Avg Co2 Change': 0.132,
#   'Population': '112,523',
#   'Density': '331',
#   'Land Size': '340',
#   'Images': 'https://www.worldometers.info/img/flags/gj-flag.gif',
#   'Lat': '12.262776',
#   'Lng': '-61.604171'},
#  {'Country': 'Guadeloupe',
#   'Avg Temp Change': 53.485,
#   'Avg Co2 Change': 0.0,
#   'Population': '400,124',
#   'Density': '237',
#   'Land Size': '1,690',
#   'Images': 0,
#   'Lat': '16.995971',
#   'Lng': '-62.067641'},
#  {'Country': 'Guatemala',
#   'Avg Temp Change': 54.25,
#   'Avg Co2 Change': 7.015,
#   'Population': '17,915,568',
#   'Density': '167',
#   'Land Size': '107,160',
#   'Images': 'https://www.worldometers.info/img/flags/gt-flag.gif',
#   'Lat': '15.783471',
#   'Lng': '-90.230759'},
#  {'Country': 'Guinea',
#   'Avg Temp Change': 54.946,
#   'Avg Co2 Change': 1.365,
#   'Population': '13,132,795',
#   'Density': '53',
#   'Land Size': '245,720',
#   'Images': 'https://www.worldometers.info/img/flags/gv-flag.gif',
#   'Lat': '9.945587',
#   'Lng': '-9.696645'},
#  {'Country': 'Guinea-Bissau',
#   'Avg Temp Change': 55.722,
#   'Avg Co2 Change': 0.165,
#   'Population': '1,968,001',
#   'Density': '70',
#   'Land Size': '28,120',
#   'Images': 'https://www.worldometers.info/img/flags/pu-flag.gif',
#   'Lat': '11.803749',
#   'Lng': '-15.180413'},
#  {'Country': 'Guyana',
#   'Avg Temp Change': 55.987,
#   'Avg Co2 Change': 1.577,
#   'Population': '786,552',
#   'Density': '4',
#   'Land Size': '196,850',
#   'Images': 'https://www.worldometers.info/img/flags/gy-flag.gif',
#   'Lat': '4.860416',
#   'Lng': '-58.93018'},
#  {'Country': 'Haiti',
#   'Avg Temp Change': 56.625,
#   'Avg Co2 Change': 1.247,
#   'Population': '11,402,528',
#   'Density': '414',
#   'Land Size': '27,560',
#   'Images': 'https://www.worldometers.info/img/flags/ha-flag.gif',
#   'Lat': '18.971187',
#   'Lng': '-72.285215'},
#  {'Country': 'Holy See',
#   'Avg Temp Change': 57.131,
#   'Avg Co2 Change': 0.0,
#   'Population': '801',
#   'Density': '2,003',
#   'Land Size': '0',
#   'Images': 'https://www.worldometers.info/img/flags/vt-flag.gif',
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Honduras',
#   'Avg Temp Change': 57.656,
#   'Avg Co2 Change': 4.149,
#   'Population': '9,904,607',
#   'Density': '89',
#   'Land Size': '111,890',
#   'Images': 'https://www.worldometers.info/img/flags/ho-flag.gif',
#   'Lat': '15.199999',
#   'Lng': '-86.241905'},
#  {'Country': 'Hungary',
#   'Avg Temp Change': 58.371,
#   'Avg Co2 Change': 65.212,
#   'Population': '9,660,351',
#   'Density': '107',
#   'Land Size': '90,530',
#   'Images': 'https://www.worldometers.info/img/flags/hu-flag.gif',
#   'Lat': '47.162494',
#   'Lng': '19.503304'},
#  {'Country': 'Iceland',
#   'Avg Temp Change': 58.599,
#   'Avg Co2 Change': 2.349,
#   'Population': '341,243',
#   'Density': '3',
#   'Land Size': '100,250',
#   'Images': 'https://www.worldometers.info/img/flags/ic-flag.gif',
#   'Lat': '64.963051',
#   'Lng': '-19.020835'},
#  {'Country': 'India',
#   'Avg Temp Change': 59.113,
#   'Avg Co2 Change': 832.208,
#   'Population': '1,380,004,385',
#   'Density': '464',
#   'Land Size': '2,973,190',
#   'Images': 'https://www.worldometers.info/img/flags/in-flag.gif',
#   'Lat': '20.593684',
#   'Lng': '78.96288'},
#  {'Country': 'Indonesia',
#   'Avg Temp Change': 59.756,
#   'Avg Co2 Change': 215.805,
#   'Population': '273,523,615',
#   'Density': '151',
#   'Land Size': '1,811,570',
#   'Images': 'https://www.worldometers.info/img/flags/id-flag.gif',
#   'Lat': '-0.789275',
#   'Lng': '113.921327'},
#  {'Country': 'Iran',
#   'Avg Temp Change': 60.634,
#   'Avg Co2 Change': 290.765,
#   'Population': '83,992,949',
#   'Density': '52',
#   'Land Size': '1,628,550',
#   'Images': 'https://www.worldometers.info/img/flags/ir-flag.gif',
#   'Lat': '32.427908',
#   'Lng': '53.688046'},
#  {'Country': 'Iraq',
#   'Avg Temp Change': 61.095,
#   'Avg Co2 Change': 72.273,
#   'Population': '40,222,493',
#   'Density': '93',
#   'Land Size': '434,320',
#   'Images': 'https://www.worldometers.info/img/flags/iz-flag.gif',
#   'Lat': '33.223191',
#   'Lng': '43.679291'},
#  {'Country': 'Ireland',
#   'Avg Temp Change': 61.547,
#   'Avg Co2 Change': 31.379,
#   'Population': '4,937,786',
#   'Density': '72',
#   'Land Size': '68,890',
#   'Images': 'https://www.worldometers.info/img/flags/ei-flag.gif',
#   'Lat': '53.41291',
#   'Lng': '-8.24389'},
#  {'Country': 'Isle of Man',
#   'Avg Temp Change': 62.115,
#   'Avg Co2 Change': 0.0,
#   'Population': '85,033',
#   'Density': '149',
#   'Land Size': '570',
#   'Images': 0,
#   'Lat': '54.236107',
#   'Lng': '-4.548056'},
#  {'Country': 'Israel',
#   'Avg Temp Change': 62.557,
#   'Avg Co2 Change': 38.783,
#   'Population': '8,655,535',
#   'Density': '400',
#   'Land Size': '21,640',
#   'Images': 'https://www.worldometers.info/img/flags/is-flag.gif',
#   'Lat': '31.046051',
#   'Lng': '34.851612'},
#  {'Country': 'Italy',
#   'Avg Temp Change': 63.44,
#   'Avg Co2 Change': 371.75,
#   'Population': '60,461,826',
#   'Density': '206',
#   'Land Size': '294,140',
#   'Images': 'https://www.worldometers.info/img/flags/it-flag.gif',
#   'Lat': '41.87194',
#   'Lng': '12.56738'},
#  {'Country': 'Japan',
#   'Avg Temp Change': 64.313,
#   'Avg Co2 Change': 997.1,
#   'Population': '126,476,461',
#   'Density': '347',
#   'Land Size': '364,555',
#   'Images': 'https://www.worldometers.info/img/flags/ja-flag.gif',
#   'Lat': '36.204824',
#   'Lng': '138.252924'},
#  {'Country': 'Jordan',
#   'Avg Temp Change': 64.858,
#   'Avg Co2 Change': 11.37,
#   'Population': '10,203,134',
#   'Density': '115',
#   'Land Size': '88,780',
#   'Images': 'https://www.worldometers.info/img/flags/jo-flag.gif',
#   'Lat': '30.585164',
#   'Lng': '36.238414'},
#  {'Country': 'Kenya',
#   'Avg Temp Change': 66.155,
#   'Avg Co2 Change': 7.267,
#   'Population': '53,771,296',
#   'Density': '94',
#   'Land Size': '569,140',
#   'Images': 'https://www.worldometers.info/img/flags/ke-flag.gif',
#   'Lat': '-0.023559',
#   'Lng': '37.906193'},
#  {'Country': 'Kuwait',
#   'Avg Temp Change': 67.54,
#   'Avg Co2 Change': 47.749,
#   'Population': '4,270,571',
#   'Density': '240',
#   'Land Size': '17,820',
#   'Images': 'https://www.worldometers.info/img/flags/ku-flag.gif',
#   'Lat': '29.31166',
#   'Lng': '47.481766'},
#  {'Country': 'Laos',
#   'Avg Temp Change': 68.388,
#   'Avg Co2 Change': 2.598,
#   'Population': '7,275,560',
#   'Density': '32',
#   'Land Size': '230,800',
#   'Images': 'https://www.worldometers.info/img/flags/la-flag.gif',
#   'Lat': '19.85627',
#   'Lng': '102.495496'},
#  {'Country': 'Lebanon',
#   'Avg Temp Change': 69.485,
#   'Avg Co2 Change': 11.683,
#   'Population': '6,825,445',
#   'Density': '667',
#   'Land Size': '10,230',
#   'Images': 'https://www.worldometers.info/img/flags/le-flag.gif',
#   'Lat': '33.854721',
#   'Lng': '35.862285'},
#  {'Country': 'Lesotho',
#   'Avg Temp Change': 70.111,
#   'Avg Co2 Change': 1.025,
#   'Population': '2,142,249',
#   'Density': '71',
#   'Land Size': '30,360',
#   'Images': 'https://www.worldometers.info/img/flags/lt-flag.gif',
#   'Lat': '-29.609988',
#   'Lng': '28.233608'},
#  {'Country': 'Liberia',
#   'Avg Temp Change': 70.746,
#   'Avg Co2 Change': 0.863,
#   'Population': '5,057,681',
#   'Density': '53',
#   'Land Size': '96,320',
#   'Images': 'https://www.worldometers.info/img/flags/li-flag.gif',
#   'Lat': '6.428055',
#   'Lng': '-9.429499'},
#  {'Country': 'Libya',
#   'Avg Temp Change': 71.222,
#   'Avg Co2 Change': 34.263,
#   'Population': '6,871,292',
#   'Density': '4',
#   'Land Size': '1,759,540',
#   'Images': 'https://www.worldometers.info/img/flags/ly-flag.gif',
#   'Lat': '26.3351',
#   'Lng': '17.228331'},
#  {'Country': 'Liechtenstein',
#   'Avg Temp Change': 72.087,
#   'Avg Co2 Change': 0.101,
#   'Population': '38,128',
#   'Density': '238',
#   'Land Size': '160',
#   'Images': 'https://www.worldometers.info/img/flags/ls-flag.gif',
#   'Lat': '47.166',
#   'Lng': '9.555373'},
#  {'Country': 'Madagascar',
#   'Avg Temp Change': 73.425,
#   'Avg Co2 Change': 1.523,
#   'Population': '27,691,018',
#   'Density': '48',
#   'Land Size': '581,795',
#   'Images': 'https://www.worldometers.info/img/flags/ma-flag.gif',
#   'Lat': '-18.766947',
#   'Lng': '46.869107'},
#  {'Country': 'Malawi',
#   'Avg Temp Change': 74.071,
#   'Avg Co2 Change': 0.763,
#   'Population': '19,129,952',
#   'Density': '203',
#   'Land Size': '94,280',
#   'Images': 'https://www.worldometers.info/img/flags/mi-flag.gif',
#   'Lat': '-13.254308',
#   'Lng': '34.301525'},
#  {'Country': 'Malaysia',
#   'Avg Temp Change': 74.621,
#   'Avg Co2 Change': 95.099,
#   'Population': '32,365,999',
#   'Density': '99',
#   'Land Size': '328,550',
#   'Images': 'https://www.worldometers.info/img/flags/my-flag.gif',
#   'Lat': '4.210484',
#   'Lng': '101.975766'},
#  {'Country': 'Mali',
#   'Avg Temp Change': 75.913,
#   'Avg Co2 Change': 0.896,
#   'Population': '20,250,833',
#   'Density': '17',
#   'Land Size': '1,220,190',
#   'Images': 'https://www.worldometers.info/img/flags/ml-flag.gif',
#   'Lat': '17.570692',
#   'Lng': '-3.996166'},
#  {'Country': 'Malta',
#   'Avg Temp Change': 76.468,
#   'Avg Co2 Change': 1.687,
#   'Population': '441,543',
#   'Density': '1,380',
#   'Land Size': '320',
#   'Images': 'https://www.worldometers.info/img/flags/mt-flag.gif',
#   'Lat': '35.937496',
#   'Lng': '14.375416'},
#  {'Country': 'Martinique',
#   'Avg Temp Change': 77.292,
#   'Avg Co2 Change': 0.0,
#   'Population': '375,265',
#   'Density': '354',
#   'Land Size': '1,060',
#   'Images': 0,
#   'Lat': '14.641528',
#   'Lng': '-61.024174'},
#  {'Country': 'Mauritania',
#   'Avg Temp Change': 78.348,
#   'Avg Co2 Change': 1.241,
#   'Population': '4,649,658',
#   'Density': '5',
#   'Land Size': '1,030,700',
#   'Images': 'https://www.worldometers.info/img/flags/mr-flag.gif',
#   'Lat': '21.00789',
#   'Lng': '-10.940835'},
#  {'Country': 'Mauritius',
#   'Avg Temp Change': 78.514,
#   'Avg Co2 Change': 1.871,
#   'Population': '1,271,768',
#   'Density': '626',
#   'Land Size': '2,030',
#   'Images': 'https://www.worldometers.info/img/flags/mp-flag.gif',
#   'Lat': '-20.348404',
#   'Lng': '57.552152'},
#  {'Country': 'Mexico',
#   'Avg Temp Change': 79.662,
#   'Avg Co2 Change': 306.124,
#   'Population': '128,932,753',
#   'Density': '66',
#   'Land Size': '1,943,950',
#   'Images': 'https://www.worldometers.info/img/flags/mx-flag.gif',
#   'Lat': '23.634501',
#   'Lng': '-102.552784'},
#  {'Country': 'Monaco',
#   'Avg Temp Change': 81.625,
#   'Avg Co2 Change': 0.0,
#   'Population': '39,242',
#   'Density': '26,337',
#   'Land Size': '1',
#   'Images': 'https://www.worldometers.info/img/flags/mn-flag.gif',
#   'Lat': '43.750298',
#   'Lng': '7.412841'},
#  {'Country': 'Mongolia',
#   'Avg Temp Change': 82.406,
#   'Avg Co2 Change': 11.613,
#   'Population': '3,278,290',
#   'Density': '2',
#   'Land Size': '1,553,560',
#   'Images': 'https://www.worldometers.info/img/flags/mg-flag.gif',
#   'Lat': '46.862496',
#   'Lng': '103.846656'},
#  {'Country': 'Morocco',
#   'Avg Temp Change': 84.055,
#   'Avg Co2 Change': 28.28,
#   'Population': '36,910,560',
#   'Density': '83',
#   'Land Size': '446,300',
#   'Images': 'https://www.worldometers.info/img/flags/mo-flag.gif',
#   'Lat': '31.791702',
#   'Lng': '-7.09262'},
#  {'Country': 'Mozambique',
#   'Avg Temp Change': 84.157,
#   'Avg Co2 Change': 2.665,
#   'Population': '31,255,435',
#   'Density': '40',
#   'Land Size': '786,380',
#   'Images': 'https://www.worldometers.info/img/flags/mz-flag.gif',
#   'Lat': '-18.665695',
#   'Lng': '35.529562'},
#  {'Country': 'Myanmar',
#   'Avg Temp Change': 84.779,
#   'Avg Co2 Change': 8.362,
#   'Population': '54,409,800',
#   'Density': '83',
#   'Land Size': '653,290',
#   'Images': 'https://www.worldometers.info/img/flags/bm-flag.gif',
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Namibia',
#   'Avg Temp Change': 85.418,
#   'Avg Co2 Change': 1.226,
#   'Population': '2,540,905',
#   'Density': '3',
#   'Land Size': '823,290',
#   'Images': 'https://www.worldometers.info/img/flags/wa-flag.gif',
#   'Lat': '-22.95764',
#   'Lng': '18.49041'},
#  {'Country': 'Nepal',
#   'Avg Temp Change': 86.303,
#   'Avg Co2 Change': 2.414,
#   'Population': '29,136,808',
#   'Density': '203',
#   'Land Size': '143,350',
#   'Images': 'https://www.worldometers.info/img/flags/np-flag.gif',
#   'Lat': '28.394857',
#   'Lng': '84.124008'},
#  {'Country': 'Netherlands',
#   'Avg Temp Change': Area
#   Netherlands    87.324
#   Netherlands    87.596
#   Name: avg_temp, dtype: float64,
#   'Avg Co2 Change': Area
#   Netherlands    154.751
#   Netherlands    154.751
#   Name: AnnualCO2emissions, dtype: float64,
#   'Population': Area
#   Netherlands    17,134,872
#   Netherlands    17,134,872
#   Name: Population, dtype: object,
#   'Density': Area
#   Netherlands    508
#   Netherlands    508
#   Name: Density, dtype: object,
#   'Land Size': Area
#   Netherlands    33,720
#   Netherlands    33,720
#   Name: Land Size, dtype: object,
#   'Images': Area
#   Netherlands    https://www.worldometers.info/img/flags/nl-fla...
#   Netherlands    https://www.worldometers.info/img/flags/nl-fla...
#   Name: Images, dtype: object,
#   'Lat': Area
#   Netherlands    52.132633
#   Netherlands    52.132633
#   Name: Lat, dtype: object,
#   'Lng': Area
#   Netherlands    5.291266
#   Netherlands    5.291266
#   Name: Lng, dtype: object},
#  {'Country': 'Netherlands',
#   'Avg Temp Change': Area
#   Netherlands    87.324
#   Netherlands    87.596
#   Name: avg_temp, dtype: float64,
#   'Avg Co2 Change': Area
#   Netherlands    154.751
#   Netherlands    154.751
#   Name: AnnualCO2emissions, dtype: float64,
#   'Population': Area
#   Netherlands    17,134,872
#   Netherlands    17,134,872
#   Name: Population, dtype: object,
#   'Density': Area
#   Netherlands    508
#   Netherlands    508
#   Name: Density, dtype: object,
#   'Land Size': Area
#   Netherlands    33,720
#   Netherlands    33,720
#   Name: Land Size, dtype: object,
#   'Images': Area
#   Netherlands    https://www.worldometers.info/img/flags/nl-fla...
#   Netherlands    https://www.worldometers.info/img/flags/nl-fla...
#   Name: Images, dtype: object,
#   'Lat': Area
#   Netherlands    52.132633
#   Netherlands    52.132633
#   Name: Lat, dtype: object,
#   'Lng': Area
#   Netherlands    5.291266
#   Netherlands    5.291266
#   Name: Lng, dtype: object},
#  {'Country': 'New Caledonia',
#   'Avg Temp Change': 88.111,
#   'Avg Co2 Change': 2.432,
#   'Population': '285,498',
#   'Density': '16',
#   'Land Size': '18,280',
#   'Images': 0,
#   'Lat': '-20.904305',
#   'Lng': '165.618042'},
#  {'Country': 'New Zealand',
#   'Avg Temp Change': 88.629,
#   'Avg Co2 Change': 25.392,
#   'Population': '4,822,233',
#   'Density': '18',
#   'Land Size': '263,310',
#   'Images': 'https://www.worldometers.info/img/flags/nz-flag.gif',
#   'Lat': '-40.900557',
#   'Lng': '174.885971'},
#  {'Country': 'Nicaragua',
#   'Avg Temp Change': 89.36,
#   'Avg Co2 Change': 2.838,
#   'Population': '6,624,554',
#   'Density': '55',
#   'Land Size': '120,340',
#   'Images': 'https://www.worldometers.info/img/flags/nu-flag.gif',
#   'Lat': '12.865416',
#   'Lng': '-85.207229'},
#  {'Country': 'Niger',
#   'Avg Temp Change': 90.037,
#   'Avg Co2 Change': 0.767,
#   'Population': '24,206,644',
#   'Density': '19',
#   'Land Size': '1,266,700',
#   'Images': 'https://www.worldometers.info/img/flags/ng-flag.gif',
#   'Lat': '17.607789',
#   'Lng': '8.081666'},
#  {'Country': 'Nigeria',
#   'Avg Temp Change': 90.609,
#   'Avg Co2 Change': 63.804,
#   'Population': '206,139,589',
#   'Density': '226',
#   'Land Size': '910,770',
#   'Images': 'https://www.worldometers.info/img/flags/ni-flag.gif',
#   'Lat': '9.081999',
#   'Lng': '8.675277'},
#  {'Country': 'Norway',
#   'Avg Temp Change': 92.918,
#   'Avg Co2 Change': 35.109,
#   'Population': '5,421,241',
#   'Density': '15',
#   'Land Size': '365,268',
#   'Images': 'https://www.worldometers.info/img/flags/no-flag.gif',
#   'Lat': '60.472024',
#   'Lng': '8.468946'},
#  {'Country': 'Oman',
#   'Avg Temp Change': 93.163,
#   'Avg Co2 Change': 20.477,
#   'Population': '5,106,626',
#   'Density': '16',
#   'Land Size': '309,500',
#   'Images': 'https://www.worldometers.info/img/flags/mu-flag.gif',
#   'Lat': '21.512583',
#   'Lng': '55.923255'},
#  {'Country': 'Pakistan',
#   'Avg Temp Change': 94.229,
#   'Avg Co2 Change': 82.221,
#   'Population': '220,892,340',
#   'Density': '287',
#   'Land Size': '770,880',
#   'Images': 'https://www.worldometers.info/img/flags/pk-flag.gif',
#   'Lat': '30.375321',
#   'Lng': '69.345116'},
#  {'Country': 'Palestine',
#   'Avg Temp Change': 95.427,
#   'Avg Co2 Change': 0.968,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Papua New Guinea',
#   'Avg Temp Change': 96.614,
#   'Avg Co2 Change': 2.756,
#   'Population': '8,947,024',
#   'Density': '20',
#   'Land Size': '452,860',
#   'Images': 'https://www.worldometers.info/img/flags/pp-flag.gif',
#   'Lat': '-6.314993',
#   'Lng': '143.95555'},
#  {'Country': 'Paraguay',
#   'Avg Temp Change': 97.277,
#   'Avg Co2 Change': 2.841,
#   'Population': '7,132,538',
#   'Density': '18',
#   'Land Size': '397,300',
#   'Images': 'https://www.worldometers.info/img/flags/pa-flag.gif',
#   'Lat': '-23.442503',
#   'Lng': '-58.443832'},
#  {'Country': 'Peru',
#   'Avg Temp Change': 97.904,
#   'Avg Co2 Change': 27.707,
#   'Population': '32,971,854',
#   'Density': '26',
#   'Land Size': '1,280,000',
#   'Images': 'https://www.worldometers.info/img/flags/pe-flag.gif',
#   'Lat': '-9.189967',
#   'Lng': '-75.015152'},
#  {'Country': 'Philippines',
#   'Avg Temp Change': 98.407,
#   'Avg Co2 Change': 53.954,
#   'Population': '109,581,078',
#   'Density': '368',
#   'Land Size': '298,170',
#   'Images': 'https://www.worldometers.info/img/flags/rp-flag.gif',
#   'Lat': '12.879721',
#   'Lng': '121.774017'},
#  {'Country': 'Poland',
#   'Avg Temp Change': 99.783,
#   'Avg Co2 Change': 345.64,
#   'Population': '37,846,611',
#   'Density': '124',
#   'Land Size': '306,230',
#   'Images': 'https://www.worldometers.info/img/flags/pl-flag.gif',
#   'Lat': '51.919438',
#   'Lng': '19.145136'},
#  {'Country': 'Portugal',
#   'Avg Temp Change': 100.297,
#   'Avg Co2 Change': 38.874,
#   'Population': '10,196,709',
#   'Density': '111',
#   'Land Size': '91,590',
#   'Images': 'https://www.worldometers.info/img/flags/po-flag.gif',
#   'Lat': '39.399872',
#   'Lng': '-8.224454'},
#  {'Country': 'Puerto Rico',
#   'Avg Temp Change': 100.574,
#   'Avg Co2 Change': 0.0,
#   'Population': '2,860,853',
#   'Density': '323',
#   'Land Size': '8,870',
#   'Images': 0,
#   'Lat': '18.220833',
#   'Lng': '-66.590149'},
#  {'Country': 'Qatar',
#   'Avg Temp Change': 101.433,
#   'Avg Co2 Change': 34.501,
#   'Population': '2,881,053',
#   'Density': '248',
#   'Land Size': '11,610',
#   'Images': 'https://www.worldometers.info/img/flags/qa-flag.gif',
#   'Lat': '25.354826',
#   'Lng': '51.183884'},
#  {'Country': 'South Korea',
#   'Avg Temp Change': 101.78,
#   'Avg Co2 Change': 287.905,
#   'Population': '51,269,185',
#   'Density': '527',
#   'Land Size': '97,230',
#   'Images': 'https://www.worldometers.info/img/flags/ks-flag.gif',
#   'Lat': '35.907757',
#   'Lng': '127.766922'},
#  {'Country': 'Romania',
#   'Avg Temp Change': 103.589,
#   'Avg Co2 Change': 125.25,
#   'Population': '19,237,691',
#   'Density': '84',
#   'Land Size': '230,170',
#   'Images': 'https://www.worldometers.info/img/flags/ro-flag.gif',
#   'Lat': '45.943161',
#   'Lng': '24.96676'},
#  {'Country': 'Saint Helena, Ascension and Tristan da Cunha',
#   'Avg Temp Change': 105.505,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Saint Lucia',
#   'Avg Temp Change': 106.238,
#   'Avg Co2 Change': 0.199,
#   'Population': '183,627',
#   'Density': '301',
#   'Land Size': '610',
#   'Images': 'https://www.worldometers.info/img/flags/st-flag.gif',
#   'Lat': '13.909444',
#   'Lng': '-60.978893'},
#  {'Country': 'Saint Pierre and Miquelon',
#   'Avg Temp Change': 106.655,
#   'Avg Co2 Change': 0.057,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Saint Vincent and the Grenadines',
#   'Avg Temp Change': 107.412,
#   'Avg Co2 Change': 0.115,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'San Marino',
#   'Avg Temp Change': 108.787,
#   'Avg Co2 Change': 0.0,
#   'Population': '33,931',
#   'Density': '566',
#   'Land Size': '60',
#   'Images': 'https://www.worldometers.info/img/flags/sm-flag.gif',
#   'Lat': '43.94236',
#   'Lng': '12.457777'},
#  {'Country': 'Saudi Arabia',
#   'Avg Temp Change': 109.798,
#   'Avg Co2 Change': 250.238,
#   'Population': '34,813,871',
#   'Density': '16',
#   'Land Size': '2,149,690',
#   'Images': 'https://www.worldometers.info/img/flags/sa-flag.gif',
#   'Lat': '23.885942',
#   'Lng': '45.079162'},
#  {'Country': 'Senegal',
#   'Avg Temp Change': 110.627,
#   'Avg Co2 Change': 3.838,
#   'Population': '16,743,927',
#   'Density': '87',
#   'Land Size': '192,530',
#   'Images': 'https://www.worldometers.info/img/flags/sg-flag.gif',
#   'Lat': '14.497401',
#   'Lng': '-14.452362'},
#  {'Country': 'Seychelles',
#   'Avg Temp Change': 111.999,
#   'Avg Co2 Change': 0.27,
#   'Population': '98,347',
#   'Density': '214',
#   'Land Size': '460',
#   'Images': 'https://www.worldometers.info/img/flags/se-flag.gif',
#   'Lat': '-4.679574',
#   'Lng': '55.491977'},
#  {'Country': 'Somalia',
#   'Avg Temp Change': 115.605,
#   'Avg Co2 Change': 0.536,
#   'Population': '15,893,222',
#   'Density': '25',
#   'Land Size': '627,340',
#   'Images': 'https://www.worldometers.info/img/flags/so-flag.gif',
#   'Lat': '5.152149',
#   'Lng': '46.199616'},
#  {'Country': 'South Africa',
#   'Avg Temp Change': 116.013,
#   'Avg Co2 Change': 311.865,
#   'Population': '59,308,690',
#   'Density': '49',
#   'Land Size': '1,213,090',
#   'Images': 'https://www.worldometers.info/img/flags/sf-flag.gif',
#   'Lat': '-30.559482',
#   'Lng': '22.937506'},
#  {'Country': 'Spain',
#   'Avg Temp Change': 117.872,
#   'Avg Co2 Change': 220.983,
#   'Population': '46,754,778',
#   'Density': '94',
#   'Land Size': '498,800',
#   'Images': 'https://www.worldometers.info/img/flags/sp-flag.gif',
#   'Lat': '40.463667',
#   'Lng': '-3.74922'},
#  {'Country': 'Sri Lanka',
#   'Avg Temp Change': 118.317,
#   'Avg Co2 Change': 7.839,
#   'Population': '21,413,249',
#   'Density': '341',
#   'Land Size': '62,710',
#   'Images': 'https://www.worldometers.info/img/flags/ce-flag.gif',
#   'Lat': '7.873054',
#   'Lng': '80.771797'},
#  {'Country': 'Suriname',
#   'Avg Temp Change': 120.075,
#   'Avg Co2 Change': 1.86,
#   'Population': '586,632',
#   'Density': '4',
#   'Land Size': '156,000',
#   'Images': 'https://www.worldometers.info/img/flags/ns-flag.gif',
#   'Lat': '3.919305',
#   'Lng': '-56.027783'},
#  {'Country': 'Svalbard and Jan Mayen Islands',
#   'Avg Temp Change': 120.934,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Sweden',
#   'Avg Temp Change': 121.331,
#   'Avg Co2 Change': 61.395,
#   'Population': '10,099,265',
#   'Density': '25',
#   'Land Size': '410,340',
#   'Images': 'https://www.worldometers.info/img/flags/sw-flag.gif',
#   'Lat': '60.128161',
#   'Lng': '18.643501'},
#  {'Country': 'Switzerland',
#   'Avg Temp Change': 121.935,
#   'Avg Co2 Change': 40.187,
#   'Population': '8,654,622',
#   'Density': '219',
#   'Land Size': '39,516',
#   'Images': 'https://www.worldometers.info/img/flags/sz-flag.gif',
#   'Lat': '46.818188',
#   'Lng': '8.227512'},
#  {'Country': 'Syria',
#   'Avg Temp Change': 122.223,
#   'Avg Co2 Change': 30.556,
#   'Population': '17,500,658',
#   'Density': '95',
#   'Land Size': '183,630',
#   'Images': 'https://www.worldometers.info/img/flags/sy-flag.gif',
#   'Lat': '34.802075',
#   'Lng': '38.996815'},
#  {'Country': 'Thailand',
#   'Avg Temp Change': 123.328,
#   'Avg Co2 Change': 120.787,
#   'Population': '69,799,978',
#   'Density': '137',
#   'Land Size': '510,890',
#   'Images': 'https://www.worldometers.info/img/flags/th-flag.gif',
#   'Lat': '15.870032',
#   'Lng': '100.992541'},
#  {'Country': 'Togo',
#   'Avg Temp Change': 124.592,
#   'Avg Co2 Change': 1.168,
#   'Population': '8,278,724',
#   'Density': '152',
#   'Land Size': '54,390',
#   'Images': 'https://www.worldometers.info/img/flags/to-flag.gif',
#   'Lat': '8.619543',
#   'Lng': '0.824782'},
#  {'Country': 'Tonga',
#   'Avg Temp Change': 125.674,
#   'Avg Co2 Change': 0.071,
#   'Population': '105,695',
#   'Density': '147',
#   'Land Size': '720',
#   'Images': 'https://www.worldometers.info/img/flags/tn-flag.gif',
#   'Lat': '-21.178986',
#   'Lng': '-175.198242'},
#  {'Country': 'Tunisia',
#   'Avg Temp Change': 127.114,
#   'Avg Co2 Change': 14.543,
#   'Population': '11,818,619',
#   'Density': '76',
#   'Land Size': '155,360',
#   'Images': 'https://www.worldometers.info/img/flags/ts-flag.gif',
#   'Lat': '33.886917',
#   'Lng': '9.537499'},
#  {'Country': 'Turkey',
#   'Avg Temp Change': 127.29,
#   'Avg Co2 Change': 171.655,
#   'Population': '84,339,067',
#   'Density': '110',
#   'Land Size': '769,630',
#   'Images': 'https://www.worldometers.info/img/flags/tu-flag.gif',
#   'Lat': '38.963745',
#   'Lng': '35.243322'},
#  {'Country': 'Tuvalu',
#   'Avg Temp Change': 128.906,
#   'Avg Co2 Change': 0.005,
#   'Population': '11,792',
#   'Density': '393',
#   'Land Size': '30',
#   'Images': 'https://www.worldometers.info/img/flags/tv-flag.gif',
#   'Lat': '-7.109535',
#   'Lng': '177.64933'},
#  {'Country': 'Uganda',
#   'Avg Temp Change': 129.632,
#   'Avg Co2 Change': 1.653,
#   'Population': '45,741,007',
#   'Density': '229',
#   'Land Size': '199,810',
#   'Images': 'https://www.worldometers.info/img/flags/ug-flag.gif',
#   'Lat': '1.373333',
#   'Lng': '32.290275'},
#  {'Country': 'United Arab Emirates',
#   'Avg Temp Change': 130.625,
#   'Avg Co2 Change': 79.129,
#   'Population': '9,890,402',
#   'Density': '118',
#   'Land Size': '83,600',
#   'Images': 'https://www.worldometers.info/img/flags/ae-flag.gif',
#   'Lat': '23.424076',
#   'Lng': '53.847818'},
#  {'Country': 'United Kingdom',
#   'Avg Temp Change': 131.272,
#   'Avg Co2 Change': 561.033,
#   'Population': '67,886,011',
#   'Density': '281',
#   'Land Size': '241,930',
#   'Images': 'https://www.worldometers.info/img/flags/uk-flag.gif',
#   'Lat': '55.378051',
#   'Lng': '-3.435973'},
#  {'Country': 'Tanzania',
#   'Avg Temp Change': 131.844,
#   'Avg Co2 Change': 3.807,
#   'Population': '59,734,218',
#   'Density': '67',
#   'Land Size': '885,800',
#   'Images': 'https://www.worldometers.info/img/flags/tz-flag.gif',
#   'Lat': '-6.369028',
#   'Lng': '34.888822'},
#  {'Country': 'United States of America',
#   'Avg Temp Change': 132.439,
#   'Avg Co2 Change': 4934.254,
#   'Population': '331,002,651',
#   'Density': '36',
#   'Land Size': '9,147,420',
#   'Images': 'https://www.worldometers.info/img/flags/us-flag.gif',
#   'Lat': '37.09024',
#   'Lng': '-95.712891'},
#  {'Country': 'United States Virgin Islands',
#   'Avg Temp Change': 132.816,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Uruguay',
#   'Avg Temp Change': 133.469,
#   'Avg Co2 Change': 5.468,
#   'Population': '3,473,730',
#   'Density': '20',
#   'Land Size': '175,020',
#   'Images': 'https://www.worldometers.info/img/flags/uy-flag.gif',
#   'Lat': '-32.522779',
#   'Lng': '-55.765835'},
#  {'Country': 'Vanuatu',
#   'Avg Temp Change': 135.239,
#   'Avg Co2 Change': 0.077,
#   'Population': '307,145',
#   'Density': '25',
#   'Land Size': '12,190',
#   'Images': 'https://www.worldometers.info/img/flags/nh-flag.gif',
#   'Lat': '-15.376706',
#   'Lng': '166.959158'},
#  {'Country': 'Venezuela',
#   'Avg Temp Change': 135.815,
#   'Avg Co2 Change': 116.086,
#   'Population': '28,435,940',
#   'Density': '32',
#   'Land Size': '882,050',
#   'Images': 'https://www.worldometers.info/img/flags/ve-flag.gif',
#   'Lat': '6.42375',
#   'Lng': '-66.58973'},
#  {'Country': 'Vietnam',
#   'Avg Temp Change': 136.329,
#   'Avg Co2 Change': 58.635,
#   'Population': '97,338,579',
#   'Density': '314',
#   'Land Size': '310,070',
#   'Images': 'https://www.worldometers.info/img/flags/vm-flag.gif',
#   'Lat': '14.058324',
#   'Lng': '108.277199'},
#  {'Country': 'Wallis and Futuna Islands',
#   'Avg Temp Change': 137.494,
#   'Avg Co2 Change': 0.008,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Western Sahara',
#   'Avg Temp Change': 138.385,
#   'Avg Co2 Change': 0.0,
#   'Population': '597,339',
#   'Density': '2',
#   'Land Size': '266,000',
#   'Images': 0,
#   'Lat': '24.215527',
#   'Lng': '-12.885834'},
#  {'Country': 'Zambia',
#   'Avg Temp Change': 139.811,
#   'Avg Co2 Change': 3.289,
#   'Population': '18,383,955',
#   'Density': '25',
#   'Land Size': '743,390',
#   'Images': 'https://www.worldometers.info/img/flags/za-flag.gif',
#   'Lat': '-13.133897',
#   'Lng': '27.849332'},
#  {'Country': 'Zimbabwe',
#   'Avg Temp Change': 140.213,
#   'Avg Co2 Change': 10.514,
#   'Population': '14,862,924',
#   'Density': '38',
#   'Land Size': '386,850',
#   'Images': 'https://www.worldometers.info/img/flags/zi-flag.gif',
#   'Lat': '-19.015438',
#   'Lng': '29.154857'},
#  {'Country': 'World',
#   'Avg Temp Change': 141.015,
#   'Avg Co2 Change': 22816.567,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Africa',
#   'Avg Temp Change': 141.55,
#   'Avg Co2 Change': 726.391,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Eastern Africa',
#   'Avg Temp Change': 142.073,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Middle Africa',
#   'Avg Temp Change': 142.589,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Northern Africa',
#   'Avg Temp Change': 143.306,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Southern Africa',
#   'Avg Temp Change': 143.762,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Western Africa',
#   'Avg Temp Change': 144.486,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Americas',
#   'Avg Temp Change': 144.942,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Northern America',
#   'Avg Temp Change': 145.548,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Central America',
#   'Avg Temp Change': 145.973,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Caribbean',
#   'Avg Temp Change': 146.647,
#   'Avg Co2 Change': 0.0,
#   'Population': '26,223',
#   'Density': '80',
#   'Land Size': '328',
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'South America',
#   'Avg Temp Change': 147.178,
#   'Avg Co2 Change': 649.369,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Asia',
#   'Avg Temp Change': 147.765,
#   'Avg Co2 Change': 8250.11,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Eastern Asia',
#   'Avg Temp Change': 148.986,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Southern Asia',
#   'Avg Temp Change': 149.333,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'South-Eastern Asia',
#   'Avg Temp Change': 149.915,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Western Asia',
#   'Avg Temp Change': 150.574,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Europe',
#   'Avg Temp Change': 151.42,
#   'Avg Co2 Change': 6400.192,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Eastern Europe',
#   'Avg Temp Change': 152.011,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Northern Europe',
#   'Avg Temp Change': 152.421,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Southern Europe',
#   'Avg Temp Change': 152.959,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Western Europe',
#   'Avg Temp Change': 153.635,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Oceania',
#   'Avg Temp Change': 153.948,
#   'Avg Co2 Change': 306.085,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Australia and New Zealand',
#   'Avg Temp Change': 154.521,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Melanesia',
#   'Avg Temp Change': 154.994,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Micronesia',
#   'Avg Temp Change': 155.471,
#   'Avg Co2 Change': 0.061,
#   'Population': '548,914',
#   'Density': '784',
#   'Land Size': '700',
#   'Images': 'https://www.worldometers.info/img/flags/fm-flag.gif',
#   'Lat': '7.425554',
#   'Lng': '150.550812'},
#  {'Country': 'Polynesia',
#   'Avg Temp Change': 156.18,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'European Union',
#   'Avg Temp Change': 156.975,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Least Developed Countries',
#   'Avg Temp Change': 157.398,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Land Locked Developing Countries',
#   'Avg Temp Change': 158.048,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Small Island Developing States',
#   'Avg Temp Change': 158.498,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Low Income Food Deficit Countries',
#   'Avg Temp Change': 159.063,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Net Food Importing Developing Countries',
#   'Avg Temp Change': 159.672,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Annex I countries',
#   'Avg Temp Change': 160.359,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'Non-Annex I countries',
#   'Avg Temp Change': 160.793,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0},
#  {'Country': 'OECD',
#   'Avg Temp Change': 161.386,
#   'Avg Co2 Change': 0.0,
#   'Population': 0,
#   'Density': 0,
#   'Land Size': 0,
#   'Images': 0,
#   'Lat': 0,
#   'Lng': 0}]
